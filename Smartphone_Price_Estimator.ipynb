# %% [markdown]
# ### Import the csv

# %%
import pandas as pd
df = pd.read_csv('smartphone.csv')

# %% [markdown]
# ### Remove faulty data

# %%
df
# Out:
#                                 model    price  rating  \
# 0                       OnePlus 11 5G  ₹54,999    89.0
# 1           OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2               Samsung Galaxy A14 5G  ₹16,499    75.0
# 3                Motorola Moto G62 5G  ₹14,999    81.0
# 4                  Realme 10 Pro Plus  ₹24,999    82.0
# ...                               ...      ...     ...
# 1015       Motorola Moto Edge S30 Pro  ₹34,990    83.0
# 1016                      Honor X8 5G  ₹14,990    75.0
# 1017  POCO X4 GT 5G (8GB RAM + 256GB)  ₹28,990    85.0
# 1018             Motorola Moto G91 5G  ₹19,990    80.0
# 1019           Samsung Galaxy M52s 5G  ₹24,990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...                                                 ...
# 1015                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1016                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1017  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1018            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1019                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                             processor  \
# 0     Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 1        Snapdragon 695, Octa Core, 2.2 GHz Processor
# 2           Exynos 1330, Octa Core, 2.4 GHz Processor
# 3       Snapdragon  695, Octa Core, 2.2 GHz Processor
# 4        Dimensity 1080, Octa Core, 2.6 GHz Processor
# ...                                               ...
# 1015    Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 1016   Snapdragon  480+, Octa Core, 2.2 GHz Processor
# 1017    Dimensity 8100, Octa Core, 2.85 GHz Processor
# 1018     Snapdragon 695, Octa Core, 2.2 GHz Processor
# 1019                              Octa Core Processor
#
#                             ram                                    battery  \
# 0     12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 100W Fast Charging
# 1      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 33W Fast Charging
# 2       4 GB RAM, 64 GB inbuilt    5000 mAh Battery with 15W Fast Charging
# 3      6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 4      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 67W Fast Charging
# ...                         ...                                        ...
# 1015   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 68.2W Fast Charging
# 1016   6 GB RAM, 128 GB inbuilt  5000 mAh Battery with 22.5W Fast Charging
# 1017   8 GB RAM, 256 GB inbuilt    5080 mAh Battery with 67W Fast Charging
# 1018   6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 1019   8 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
#
#                                                 display  \
# 0     6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1     6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2     6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3     6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4     6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# ...                                                 ...
# 1015  6.67 inches, 1080 x 2460 px, 120 Hz Display wi...
# 1016  6.5 inches, 720 x 1600 px Display with Water D...
# 1017  6.6 inches, 1080 x 2460 px, 144 Hz Display wit...
# 1018  6.8 inches, 1080 x 2400 px Display with Punch ...
# 1019  6.5 inches, 1080 x 2400 px Display with Water ...
#
#                                                  camera  \
# 0     50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2     50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4     108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# ...                                                 ...
# 1015  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1016  48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP...
# 1017  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1018  108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...
# 1019  64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
#
#                                   card           os
# 0            Memory Card Not Supported  Android v13
# 1      Memory Card (Hybrid), upto 1 TB  Android v12
# 2     Memory Card Supported, upto 1 TB  Android v13
# 3      Memory Card (Hybrid), upto 1 TB  Android v12
# 4            Memory Card Not Supported  Android v13
# ...                                ...          ...
# 1015                       Android v12  No FM Radio
# 1016  Memory Card Supported, upto 1 TB  Android v11
# 1017         Memory Card Not Supported  Android v12
# 1018  Memory Card Supported, upto 1 TB  Android v12
# 1019  Memory Card Supported, upto 1 TB  Android v12
#
# [1020 rows x 11 columns]

# %%
for st in df.columns:
    print(st+":\n")
    print(df[st].unique())
# Out:
# model:
#
# ['OnePlus 11 5G' 'OnePlus Nord CE 2 Lite 5G' 'Samsung Galaxy A14 5G' ...
#  'POCO X4 GT 5G (8GB RAM + 256GB)' 'Motorola Moto G91 5G'
#  'Samsung Galaxy M52s 5G']
# price:
#
# ['₹54,999' '₹19,989' '₹16,499' '₹14,999' '₹24,999' '₹16,999' '₹65,999'
#  '₹29,999' '₹26,749' '₹28,999' '₹18,999' '₹24,762' '₹16,990' '₹1,14,990'
#  '₹62,999' '₹9,999' '₹45,999' '₹32,999' '₹14,499' '₹39,999' '₹35,999'
#  '₹17,859' '₹42,990' '₹31,239' '₹21,995' '₹1,29,990' '₹27,999' '₹69,999'
#  '₹19,999' '₹20,999' '₹27,990' '₹38,999' '₹23,790' '₹29,990' '₹91,999'
#  '₹28,499' '₹21,999' '₹18,499' '₹17,478' '₹11,936' '₹8,950' '₹12,489'
#  '₹42,999' '₹11,990' '₹13,999' '₹14,965' '₹74,999' '₹10,999' '₹84,990'
#  '₹10,499' '₹17,990' '₹35,499' '₹60,999' '₹15,999' '₹99,990' '₹9,499'
#  '₹27,994' '₹13,989' '₹44,999' '₹6,190' '₹1,19,900' '₹27,660' '₹8,388'
#  '₹19,990' '₹22,999' '₹14,290' '₹41,999' '₹13,489' '₹22,990' '₹73,999'
#  '₹12,499' '₹59,999' '₹1,06,990' '₹15,990' '₹1,19,990' '₹23,990' '₹12,999'
#  '₹58,990' '₹43,999' '₹49,999' '₹36,999' '₹51,999' '₹31,999' '₹6,171'
#  '₹29,340' '₹25,289' '₹21,788' '₹70,990' '₹34,999' '₹33,900' '₹19,499'
#  '₹24,994' '₹25,999' '₹34,990' '₹13,466' '₹7,999' '₹28,249' '₹46,999'
#  '₹13,490' '₹15,499' '₹4,499' '₹8,499' '₹24,990' '₹9,589' '₹40,999'
#  '₹19,988' '₹11,999' '₹1,42,990' '₹30,990' '₹4,990' '₹5,299' '₹25,969'
#  '₹94,990' '₹1,29,900' '₹41,990' '₹17,999' '₹5,499' '₹20,499' '₹20,490'
#  '₹15,490' '₹21,990' '₹6,999' '₹8,099' '₹3,499' '₹9,990' '₹11,828'
#  '₹14,450' '₹71,999' '₹11,499' '₹1,39,990' '₹81,999' '₹31,994' '₹9,299'
#  '₹25,900' '₹12,188' '₹8,999' '₹7,499' '₹65,499' '₹18,990' '₹26,990'
#  '₹13,969' '₹53,100' '₹21,899' '₹75,999' '₹46,990' '₹16,940' '₹20,990'
#  '₹64,449' '₹8,990' '₹13,499' '₹6,499' '₹36,499' '₹39,990' '₹6,199'
#  '₹54,300' '₹22,700' '₹50,990' '₹64,900' '₹13,799' '₹89,999' '₹21,994'
#  '₹69,990' '₹26,999' '₹16,900' '₹1,82,999' '₹7,749' '₹25,895' '₹7,790'
#  '₹6,299' '₹21,890' '₹55,999' '₹25,994' '₹33,499' '₹1,18,999' '₹6,990'
#  '₹12,944' '₹64,999' '₹1,54,998' '₹1,09,999' '₹84,999' '₹27,499' '₹40,480'
#  '₹1,05,999' '₹23,399' '₹22,998' '₹11,700' '₹64,800' '₹14,590' '₹72,999'
#  '₹77,990' '₹56,999' '₹4,649' '₹18,000' '₹7,145' '₹14,990' '₹59,990'
#  '₹89,990' '₹50,999' '₹1,34,999' '₹35,489' '₹20,120' '₹28,994' '₹48,900'
#  '₹22,494' '₹8,890' '₹18,498' '₹23,999' '₹22,994' '₹12,990' '₹12,120'
#  '₹6,490' '₹2,999' '₹1,49,900' '₹1,04,999' '₹79,999' '₹36,760' '₹23,499'
#  '₹75,990' '₹7,249' '₹23,890' '₹26,380' '₹10,850' '₹36,994' '₹14,700'
#  '₹13,990' '₹6,50,000' '₹14,859' '₹15,824' '₹43,900' '₹19,650' '₹1,30,990'
#  '₹12,787' '₹63,990' '₹34,949' '₹8,799' '₹12,390' '₹1,99,990' '₹8,910'
#  '₹1,762' '₹12,364' '₹3,990' '₹5,990' '₹1,13,990' '₹2,39,999' '₹6,899'
#  '₹92,980' '₹60,990' '₹8,859' '₹33,749' '₹11,600' '₹8,299' '₹7,289'
#  '₹14,490' '₹36,000' '₹10,630' '₹14,489' '₹16,490' '₹24,494' '₹49,959'
#  '₹23,269' '₹1,949' '₹2,799' '₹35,389' '₹79,700' '₹12,340' '₹10,799'
#  '₹61,990' '₹51,880' '₹57,999' '₹17,499' '₹49,990' '₹2,399' '₹19,980'
#  '₹35,990' '₹7,990' '₹24,499' '₹1,10,999' '₹1,299' '₹25,000' '₹1,999'
#  '₹9,950' '₹28,498' '₹15,998' '₹3,749' '₹24,820' '₹12,490' '₹99,999'
#  '₹1,09,900' '₹52,990' '₹99' '₹699' '₹28,990' '₹14,799' '₹23,994' '₹3,589'
#  '₹1,39,900' '₹86,000' '₹26,499' '₹95,999' '₹47,990' '₹5,490' '₹1,339'
#  '₹16,685' '₹39,900' '₹5,999' '₹958' '₹6,699' '₹8,968' '₹7,320' '₹14,746'
#  '₹25,990' '₹23,500' '₹79,990' '₹92,999' '₹1,799' '₹32,990' '₹5,785'
#  '₹82,199' '₹1,850' '₹92,249' '₹15,988' '₹11,725' '₹17,994' '₹25,595'
#  '₹10,890' '₹58,999' '₹12,500' '₹31,990' '₹1,07,990' '₹48,990' '₹1,62,990'
#  '₹82,990' '₹5,249' '₹44,990' '₹22,490' '₹27,000' '₹3,290' '₹13,279'
#  '₹11,000' '₹18,900' '₹7,299' '₹995' '₹54,990' '₹1,69,900' '₹53,990'
#  '₹88,999' '₹6,249' '₹1,79,900' '₹10,990' '₹1,09,990' '₹12,199' '₹11,490'
#  '₹59,450' '₹12,799' '₹83,000' '₹9,490' '₹15,000' '₹1,24,990' '₹1,72,999'
#  '₹13,774' '₹2,239' '₹11,399' '₹599' '₹9,690' '₹18,699' '₹1,749' '₹3,099'
#  '₹12,989' '₹4,999' '₹8,199' '₹20,000' '₹11,989' '₹78,990' '₹10,949'
#  '₹10,300' '₹1,899' '₹1,599' '₹4,799' '₹10,490' '₹11,879' '₹1,49,999'
#  '₹3,999' '₹1,01,999' '₹38,700' '₹67,999' '₹14,439' '₹2,499' '₹85,990'
#  '₹4,80,000' '₹3,890' '₹1,685' '₹2,099' '₹649' '₹9,022' '₹8,399' '₹8,390'
#  '₹1,63,980' '₹40,990' '₹1,18,990' '₹7,399' '₹1,47,900' '₹30,994'
#  '₹19,000' '₹5,890' '₹3,399' '₹2,14,990' '₹1,69,000' '₹21,490' '₹6,799'
#  '₹25,899' '₹8,720' '₹4,787']
# rating:
#
# [89. 81. 75. 82. 80. 86. 85. 84. 79. nan 65. 72. 76. 87. 88. 83. 73. 64.
#  68. 74. 78. 62. 66. 69. 67. 71. 77. 61. 60. 63. 70.]
# sim:
#
# ['Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC'
#  'Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi'
#  'Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster'
#  'Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC'
#  'Dual Sim, 3G, 4G, VoLTE, Wi-Fi'
#  'Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Blaster'
#  'Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC'
#  'Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster' 'Dual Sim, 3G, 4G, Wi-Fi'
#  'Single Sim, 3G, 4G, VoLTE, Wi-Fi, NFC'
#  'Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC'
#  'Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi' 'Dual Sim, 3G, 4G'
#  'Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi' 'Single Sim, 3G, 4G, Wi-Fi, NFC'
#  'Dual Sim, 3G, 4G, VoLTE'
#  'Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster' 'Dual Sim' 'Single Sim'
#  'Single Sim, 3G, 4G, VoLTE, Wi-Fi' 'Dual Sim, 3G, Wi-Fi'
#  'Dual Sim, Wi-Fi' 'Dual Sim, 3G, 4G, Wi-Fi, NFC'
#  'Dual Sim, 4G, VoLTE, Wi-Fi' 'Wi-Fi'
#  'Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, IR Blaster'
#  'Single Sim, 3G, 4G, Wi-Fi'
#  'Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC, IR Blaster']
# processor:
#
# ['Snapdragon 8 Gen2, Octa Core, 3.2\u2009GHz Processor'
#  'Snapdragon 695, Octa Core, 2.2\u2009GHz Processor'
#  'Exynos 1330, Octa Core, 2.4\u2009GHz Processor'
#  'Snapdragon  695, Octa Core, 2.2\u2009GHz Processor'
#  'Dimensity 1080, Octa Core, 2.6\u2009GHz Processor'
#  'Snapdragon  750G, Octa Core, 2.2\u2009GHz Processor'
#  'Bionic A15, Hexa Core, 3.22\u2009GHz Processor'
#  'Snapdragon 778G Plus, Octa Core, 2.5\u2009GHz Processor'
#  'Dimensity  1300, Octa Core, 3\u2009GHz Processor'
#  'Dimensity 700 5G, Octa Core, 2.2\u2009GHz Processor'
#  'Helio P35, Octa Core, 2.3\u2009GHz Processor'
#  'Snapdragon 8+ Gen1, Octa Core, 3.2\u2009GHz Processor'
#  'Dimensity 8100 Max, Octa Core, 2.85\u2009GHz Processor'
#  'Helio G70, Octa Core, 2\u2009GHz Processor'
#  'Snapdragon  8+ Gen1, Octa Core, 3.2\u2009GHz Processor'
#  'Dimensity 1300, Octa Core, 3\u2009GHz Processor'
#  'Snapdragon 695 , Octa Core, 2.2\u2009GHz Processor'
#  'Snapdragon 4 Gen 1, Octa Core, 2\u2009GHz Processor'
#  'Dimensity 9000 Plus, Octa Core, 3.2\u2009GHz Processor'
#  'Snapdragon 865, Octa Core, 2.84\u2009GHz Processor'
#  'Bionic  A16, Hexa Core Processor'
#  'Dimensity  900, Octa Core, 2\u2009GHz Processor'
#  'Snapdragon  8 Gen2, Octa Core, 3.2\u2009GHz Processor'
#  'Snapdragon 778G, Octa Core, 2.4\u2009GHz Processor'
#  'Dimensity  930, Octa Core, 2.2\u2009GHz Processor'
#  'A13 Bionic, Hexa Core, 2.65\u2009GHz Processor'
#  'Dimensity  900 5G, Octa Core, 2.4\u2009GHz Processor'
#  'Exynos  2100, Octa Core, 2.9\u2009GHz Processor'
#  'Snapdragon  8 Gen1, Octa Core, 3\u2009GHz Processor'
#  'Snapdragon  7 Gen1, Octa Core, 2.36\u2009GHz Processor'
#  ' Snapdragon  695, Octa Core, 2.2\u2009GHz Processor'
#  'Dimensity 800U, Octa Core, 2.4\u2009GHz Processor'
#  'Snapdragon 680, Octa Core, 2.4\u2009GHz Processor'
#  'Exynos  1280, Octa Core, 2.4\u2009GHz Processor'
#  'Snapdragon  680, Octa Core, 2.4\u2009GHz Processor'
#  'Unisoc T612, Octa Core, 1.8\u2009GHz Processor'
#  'Snapdragon 7 Gen1, Octa Core, 2.36\u2009GHz Processor'
#  'Dimensity 8200, Octa Core, 3.1\u2009GHz Processor'
#  'Snapdragon 480+, Octa Core, 2.2\u2009GHz Processor'
#  'Helio G99, Octa Core, 2.2\u2009GHz Processor'
#  'Dimensity 810 5G, Octa Core, 2.4\u2009GHz Processor'
#  'Helio G95, Octa Core, 2.05\u2009GHz Processor'
#  'Dimensity 720, Octa Core, 2\u2009GHz Processor'
#  'Snapdragon 870, Octa Core, 3.2\u2009GHz Processor'
#  'Dimensity  810 5G, Octa Core, 2.4\u2009GHz Processor'
#  'Helio G35, Octa Core, 2.3\u2009GHz Processor'
#  'Dimensity  920 5G, Octa Core, 2.5\u2009GHz Processor'
#  'Snapdragon  4 Gen 1, Octa Core, 2\u2009GHz Processor'
#  'Dimensity 700 , Octa Core, 2.2\u2009GHz Processor'
#  'Tiger  T310, Quad Core, 2\u2009GHz Processor'
#  'Snapdragon 6 Gen 1, Octa Core, 2.2\u2009GHz Processor'
#  'Exynos 1280, Octa Core Processor'
#  'Helio  G25, Octa Core, 2\u2009GHz Processor'
#  'Helio  G99, Octa Core, 2.2\u2009GHz Processor'
#  'Dimensity 700, Octa Core, 2.2\u2009GHz Processor'
#  'Snapdragon 778G+, Octa Core, 2.5\u2009GHz Processor'
#  'Snapdragon 8 Gen1, Octa Core, 3\u2009GHz Processor'
#  'Snapdragon 888+, Octa Core, 2.9\u2009GHz Processor'
#  'Dimensity 800U , Octa Core, 2.4\u2009GHz Processor'
#  'Dimensity 9000, Octa Core, 3.05\u2009GHz Processor'
#  'Bionic A14, Hexa Core, 3.1\u2009GHz Processor'
#  'Dimensity  8100, Octa Core, 2.85\u2009GHz Processor'
#  'Exynos 1280, Octa Core, 2.4\u2009GHz Processor'
#  'Helio A22, Quad Core, 2\u2009GHz Processor'
#  'Snapdragon  778G, Octa Core, 2.4\u2009GHz Processor'
#  'Octa Core Processor' 'Google  Tensor, Octa Core Processor'
#  'Snapdragon 720G, Octa Core, 2.3\u2009GHz Processor'
#  'Tiger T700, Octa Core, 1.8\u2009GHz Processor'
#  'Tiger  T616, Octa Core, 1.8\u2009GHz Processor'
#  'Snapdragon  695 , Octa Core, 2.2\u2009GHz Processor'
#  'Quad Core, 1.4\u2009GHz Processor'
#  'Snapdragon 460 , Octa Core, 1.8\u2009GHz Processor'
#  'Exynos 1200, Octa Core, 2.4\u2009GHz Processor' 'Bionic  A16'
#  'Snapdragon QM215, Quad Core, 1.3\u2009GHz Processor'
#  'Tiger T612, Octa Core, 1.82\u2009GHz Processor'
#  ' Snapdragon 695, Octa Core, 2.2\u2009GHz Processor'
#  'Dimensity 9200, Octa Core, 3.05\u2009GHz Processor'
#  'Exynos 850, Octa Core, 2\u2009GHz Processor'
#  'Snapdragon  888 , Octa Core, 2.84\u2009GHz Processor'
#  'Dimensity 810, Octa Core, 2.4\u2009GHz Processor'
#  'Tiger T310, Quad Core, 2\u2009GHz Processor'
#  'Snapdragon  480 , Octa Core, 2\u2009GHz Processor'
#  'Helio G96, Octa Core, 2\u2009GHz Processor'
#  'Dimensity  700 5G, Octa Core, 2.2\u2009GHz Processor'
#  'Helio G96, Octa Core, 2.05\u2009GHz Processor'
#  'Dimensity 920 5G, Octa Core, 2.5\u2009GHz Processor'
#  'Dimensity  8200, Octa Core, 3.1\u2009GHz Processor'
#  'Quad Core, 1.6\u2009GHz Processor'
#  'Tiger T7150, Quad Core, 1.8\u2009GHz Processor'
#  'Helio  P22 , Octa Core, 2\u2009GHz Processor'
#  'Helio  G85, Octa Core, 2\u2009GHz Processor'
#  'Snapdragon 888, Octa Core, 2.84\u2009GHz Processor'
#  'Dimensity 8100-Max, Octa Core, 2.85\u2009GHz Processor'
#  'Octa Core, 2\u2009GHz Processor' 'Exynos 1380, Octa Core Processor'
#  'Google  Tensor G2, Octa Core, 2.85\u2009GHz Processor'
#  'Helio G88, Octa Core, 2\u2009GHz Processor'
#  'Dimensity 1200, Octa Core, 3\u2009GHz Processor'
#  'Helio, Octa Core Processor'
#  'Snapdragon  8+ Gen1 , Octa Core, 3.2\u2009GHz Processor'
#  'Snapdragon 778G+, Octa Core Processor'
#  'Google Tensor G2, Octa Core, 2.85\u2009GHz Processor'
#  'Dimensity 930, Octa Core, 2.2\u2009GHz Processor'
#  'Exynos  2300, Octa Core Processor'
#  'Dimensity 900, Octa Core, 2.4\u2009GHz Processor' 'Apple  A13'
#  'Dimensity  1200 Max, Octa Core, 3\u2009GHz Processor'
#  'Snapdragon 712, Octa Core, 2.3\u2009GHz Processor'
#  'Helio G80, Octa Core, 2\u2009GHz Processor'
#  'Snapdragon 205 , Dual Core, 1.1\u2009GHz Processor'
#  'Google  Tensor, Octa Core, 2.8\u2009GHz Processor'
#  'Helio G85, Octa Core, 2\u2009GHz Processor' 'Bionic A16'
#  'Exynos  850, Octa Core, 2\u2009GHz Processor'
#  'SC9863A, Octa Core, 1.6\u2009GHz Processor'
#  'Snapdragon  480+, Octa Core, 2.2\u2009GHz Processor'
#  'Snapdragon  778G , Octa Core, 2.4\u2009GHz Processor'
#  'Dimensity 900, Octa Core, 2\u2009GHz Processor'
#  'Quad Core, 1.3\u2009GHz Processor'
#  'Dimensity  900, Octa Core, 2.4\u2009GHz Processor'
#  'Helio G37, Octa Core, 2.3\u2009GHz Processor'
#  'Google Tensor, Octa Core, 2.8\u2009GHz Processor'
#  'Snapdragon 732G , Octa Core, 2.3\u2009GHz Processor'
#  'Snapdragon  870, Octa Core, 3.2\u2009GHz Processor'
#  'Unisoc  SC9836A, Quad Core, 1.6\u2009GHz Processor'
#  'Snapdragon  732G, Octa Core, 2.3\u2009GHz Processor'
#  'Helio  G96, Octa Core, 2.05\u2009GHz Processor'
#  'Helio  G37, Octa Core, 2.3\u2009GHz Processor'
#  'Helio G25, Octa Core, 2\u2009GHz Processor'
#  'Qualcomm 215, Quad Core, 1.3\u2009GHz Processor'
#  'Helio P22, Octa Core, 2\u2009GHz Processor'
#  'Unisoc SC9863A, Octa Core, 1.6\u2009GHz Processor'
#  'Snapdragon  888+, Octa Core, 2.9\u2009GHz Processor'
#  'Snapdragon 8+ Gen 2, Octa Core Processor'
#  'Snapdragon 765G , Octa Core, 2.4\u2009GHz Processor'
#  'Exynos 990, Octa Core, 2.73\u2009GHz Processor'
#  'Snapdragon 855, Octa Core, 2.8\u2009GHz Processor'
#  'Exynos 9820, Octa Core, 2.7\u2009GHz Processor' 'No Wifi'
#  'Snapdragon 730, Octa Core, 2.2\u2009GHz Processor'
#  'Unisoc, Octa Core Processor'
#  'Unisoc  T606, Octa Core, 2\u2009GHz Processor'
#  'Snapdragon 662 , Octa Core, 2\u2009GHz Processor'
#  'Helio G95, Octa Core, 2\u2009GHz Processor'
#  'Spreadtrum  SC7731E, Quad Core, 1.3\u2009GHz Processor'
#  'Dual Core, 1\u2009GHz Processor' 'Bionic  A17, Octa Core Processor'
#  'Snapdragon  810, Octa Core, 2.4\u2009GHz Processor'
#  'Unisoc  T606, Octa Core, 1.6\u2009GHz Processor'
#  'Snapdragon  778G Plus, Octa Core, 2.5\u2009GHz Processor'
#  'Snapdragon 775' 'Snapdragon 678, Octa Core, 2.2\u2009GHz Processor'
#  'Snapdragon 801, Octa Core, 1.5\u2009GHz Processor'
#  'Bionic  A15, Hexa Core, 3.22\u2009GHz Processor'
#  'Snapdragon  720G, Octa Core, 2.3\u2009GHz Processor'
#  'Snapdragon 860, Octa Core, 2.96\u2009GHz Processor'
#  'Dimensity  9000, Octa Core, 3.05\u2009GHz Processor'
#  'Helio  P35, Octa Core, 2.3\u2009GHz Processor'
#  'Helio G85 , Octa Core, 2\u2009GHz Processor'
#  'Snapdragon 855+, Octa Core, 2.96\u2009GHz Processor'
#  'Unisoc T606, Octa Core, 1.6\u2009GHz Processor'
#  'Tiger T610, Octa Core, 1.82\u2009GHz Processor'
#  'Unisoc  SC9863A, Octa Core, 1.6\u2009GHz Processor'
#  'Helio  G95, Octa Core, 2.05\u2009GHz Processor'
#  'Snapdragon 845, Octa Core, 2.8\u2009GHz Processor'
#  'Helio MT6580, Quad Core, 1.3\u2009GHz Processor'
#  'Snapdragon 615, Octa Core, 1.5\u2009GHz Processor'
#  'Tiger T606, Octa Core, 2\u2009GHz Processor'
#  'Unisoc  SC9832E, Quad Core, 1.4\u2009GHz Processor'
#  'Snapdragon  210, Quad Core, 1.1\u2009GHz Processor'
#  'Snapdragon 865 , Octa Core, 2.84\u2009GHz Processor'
#  'Sanpdragon 680, Octa Core, 2.4\u2009GHz Processor'
#  'Helio G37, Octa Core, 1.8\u2009GHz Processor'
#  'Dimensity 8100, Octa Core, 2.85\u2009GHz Processor'
#  'Snapdragon 835, Octa Core, 2.35\u2009GHz Processor'
#  'Helio P35 , Octa Core, 2.3\u2009GHz Processor'
#  'Snapdragon  680 , Octa Core, 2.4\u2009GHz Processor'
#  'Snapdragon 888+ , Octa Core, 2.9\u2009GHz Processor'
#  'Snapdragon  720G , Octa Core, 2.3\u2009GHz Processor'
#  '1\u2009GHz Processor' 'Tiger T616, Octa Core, 2\u2009GHz Processor'
#  'No 3G' 'Exynos  990, Octa Core, 2.73\u2009GHz Processor'
#  'Snapdragon  765G , Octa Core, 2.4\u2009GHz Processor'
#  'Snapdragon 425, Quad Core, 1.4\u2009GHz Processor'
#  'Snapdragon MSM8909, Quad Core, 1.1\u2009GHz Processor'
#  'Snapdragon 720G , Octa Core, 2.3\u2009GHz Processor'
#  'Snapdragon 690, Octa Core, 2\u2009GHz Processor'
#  'Fusion APL1024, Quad Core, 2.37\u2009GHz Processor'
#  '1\u2009GB RAM, 4\u2009GB inbuilt'
#  'Unisoc T610, Octa Core, 1.8\u2009GHz Processor' 'Unisoc T117'
#  'Snapdragon  865 , Octa Core, 2.84\u2009GHz Processor'
#  'Snapdragon 732G, Octa Core, 2.3\u2009GHz Processor'
#  '4\u2009MB RAM, 4\u2009MB inbuilt' '1450\u2009mAh Battery'
#  'Kirin  9000, Octa Core, 3.13\u2009GHz Processor'
#  'Unisoc  T610, Octa Core, 1.8\u2009GHz Processor'
#  '32\u2009MB RAM, 32\u2009MB inbuilt'
#  'Tiger T610, Quad Core, 1.8\u2009GHz Processor'
#  'Dimensity  9200, Octa Core Processor'
#  'Dimensity 700, Octa Core, 2\u2009GHz Processor'
#  'Snapdragon  6 Gen 1, Octa Core, 2.2\u2009GHz Processor'
#  'Unisoc  SC9863a, Octa Core, 1.6\u2009GHz Processor'
#  'Tiger  T610, Octa Core, 1.8\u2009GHz Processor'
#  'Dimensity 1100 5G, Octa Core, 2.6\u2009GHz Processor'
#  'Snapdragon  765G, Octa Core, 2.4\u2009GHz Processor'
#  'Snapdragon 730G, Octa Core, 2.2\u2009GHz Processor'
#  'Snapdragon  865, Octa Core, 2.84\u2009GHz Processor'
#  'Exynos 9810, Octa Core, 2.7\u2009GHz Processor'
#  'Exynos 9825, Octa Core, 2.7\u2009GHz Processor' 'Helio MT6260A'
#  'Exynos 7904, Octa Core, 1.8\u2009GHz Processor' '800\u2009mAh Battery'
#  'Snapdragon  888, Octa Core, 2.84\u2009GHz Processor'
#  'Exynos 9611, Octa Core, 2.3\u2009GHz Processor'
#  'Helio P95, Octa Core, 2.2\u2009GHz Processor'
#  'Helio P60, Octa Core, 1.99\u2009GHz Processor'
#  'Snapdragon  750G , Octa Core, 2.2\u2009GHz Processor'
#  'Exynos  9611 , Octa Core, 2.3\u2009GHz Processor'
#  'Exynos 9825, Octa Core, 2.73\u2009GHz Processor'
#  'Snapdragon  665, Octa Core, 2\u2009GHz Processor'
#  'Snapdragon  782G, Octa Core, 2.7\u2009GHz Processor'
#  'Dimensity 8100 Ultra, Octa Core, 2.85\u2009GHz Processor'
#  'Kirin 9000E, Octa Core, 3.13\u2009GHz Processor'
#  'Helio A25, Octa Core, 1.8\u2009GHz Processor'
#  'Spreadtrum  SC7731, Quad Core, 1.3\u2009GHz Processor'
#  'Snapdragon 662, Octa Core, 2\u2009GHz Processor'
#  'Unisoc SC7731E, Quad Core, 1.3\u2009GHz Processor'
#  'Snapdragon  712 , Octa Core, 2.3\u2009GHz Processor'
#  '2000\u2009mAh Battery'
#  'Snapdragon  675, Octa Core, 2\u2009GHz Processor'
#  'Snapdragon  730G, Octa Core, 2.2\u2009GHz Processor'
#  'Helio  P22, Octa Core, 2\u2009GHz Processor' '32\u2009GB inbuilt'
#  '52\u2009MB RAM, 32\u2009MB inbuilt'
#  'Dimensity 9200, Octa Core Processor'
#  'Snapdragon 8 Gen1 , Octa Core, 3\u2009GHz Processor'
#  'Google Tensor 3, Octa Core Processor'
#  'Octa Core, 2.2\u2009GHz Processor'
#  'Snapdragon  439 , Octa Core, 2\u2009GHz Processor'
#  'Tiger T610, Octa Core, 1.8\u2009GHz Processor'
#  'Snapdragon  662 , Octa Core, 2\u2009GHz Processor'
#  'Exynos 2100, Octa Core, 2.9\u2009GHz Processor'
#  'Kirin 990, Octa Core, 2.86\u2009GHz Processor'
#  'Snapdragon 439, Octa Core, 2\u2009GHz Processor'
#  'Snapdragon 675, Octa Core, 2\u2009GHz Processor'
#  'Snapdragon 439, Octa Core, 1.95\u2009GHz Processor'
#  'Helio P60, Octa Core, 2\u2009GHz Processor'
#  'Exynos 9810, Octa Core, 2.8\u2009GHz Processor'
#  'Exynos 1330, Octa Core Processor'
#  'Snapdragon  778G+, Octa Core Processor' '1.77\u2009MHz Processor'
#  'Snapdragon 680 , Octa Core, 2.4\u2009GHz Processor'
#  'SC6531E, 26\u2009MHz Processor'
#  'Helio   G90T , Octa Core, 2.05\u2009GHz Processor'
#  '(28 nm), Quad Core, 1.5\u2009GHz Processor'
#  '1\u2009GB RAM, 8\u2009GB inbuilt'
#  'Kirin  810, Octa Core, 2.2\u2009GHz Processor'
#  'Helio  P65 , Octa Core, 2\u2009GHz Processor'
#  'Helio P70, Octa Core, 2\u2009GHz Processor'
#  'Qualcomm Snapdragon 670, Octa Core, 2\u2009GHz Processor'
#  'Samsung Exynos 7885, Octa Core, 2.2\u2009GHz Processor'
#  'Kirin 659, Octa Core, 2.36\u2009GHz Processor'
#  'Qualcomm Snapdragon 625, Octa Core, 2\u2009GHz Processor'
#  'Single Core, 1\u2009GHz Processor'
#  'Snapdragon  7 Gen2, Octa Core Processor'
#  'Snapdragon  7 Gen1, Octa Core, 2.4\u2009GHz Processor'
#  'Helio  G88, Octa Core, 2\u2009GHz Processor'
#  'Snapdragon  690 , Octa Core, 2\u2009GHz Processor'
#  'Spreadtrum  SC9832E , Quad Core, 1.4\u2009GHz Processor'
#  'Dimensity 1000+, Octa Core, 2.6\u2009GHz Processor'
#  'Snapdragon 665, Octa Core, 2\u2009GHz Processor'
#  'Snapdragon 460, Octa Core, 1.8\u2009GHz Processor'
#  'Helio P35, Octa Core, 1.8\u2009GHz Processor'
#  'Snapdragon  855, Octa Core, 2.8\u2009GHz Processor'
#  'Helio  G90T, Octa Core, 2.05\u2009GHz Processor'
#  'Helio P70, Octa Core, 2.1\u2009GHz Processor'
#  'Helio P23, Octa Core, 2.5\u2009GHz Processor'
#  '256\u2009MB RAM, 512\u2009MB inbuilt'
#  'Snapdragon MSM8939, Octa Core, 1.5\u2009GHz Processor'
#  'Bionic A16, Hexa Core Processor' '48\u2009MB RAM, 128\u2009MB inbuilt'
#  'Snapdragon 870 , Octa Core, 3.2\u2009GHz Processor'
#  'Snapdragon 7 Gen1, Octa Core, 2.4\u2009GHz Processor'
#  'Snapdragon 765G, Octa Core, 2.4\u2009GHz Processor'
#  'Unisoc  A55, Octa Core, 1.6\u2009GHz Processor'
#  'Snapdragon 450, Octa Core, 1.8\u2009GHz Processor'
#  '8\u2009MB RAM, 16\u2009MB inbuilt'
#  'Kirin  990, Octa Core, 2.86\u2009GHz Processor'
#  'Octa Core, 1.8\u2009GHz Processor'
#  'Snapdragon 710, Octa Core, 2.2\u2009GHz Processor'
#  'Exynos 7885, Octa Core, 2.2\u2009GHz Processor'
#  'Snapdragon 425, Quad Core, 1.2\u2009GHz Processor'
#  'Spreadtrum  SC9832E, Quad Core, 1.4\u2009GHz Processor'
#  'Google  Tensor 3, Octa Core Processor']
# ram:
#
# ['12\u2009GB RAM, 256\u2009GB inbuilt'
#  '6\u2009GB RAM, 128\u2009GB inbuilt' '4\u2009GB RAM, 64\u2009GB inbuilt'
#  '8\u2009GB RAM, 256\u2009GB inbuilt' '8\u2009GB RAM, 128\u2009GB inbuilt'
#  '4\u2009GB RAM, 128\u2009GB inbuilt' '3\u2009GB RAM, 32\u2009GB inbuilt'
#  '16\u2009GB RAM, 256\u2009GB inbuilt' '6\u2009GB RAM, 64\u2009GB inbuilt'
#  '4\u2009GB RAM, 32\u2009GB inbuilt' '3\u2009GB RAM, 64\u2009GB inbuilt'
#  '2\u2009GB RAM, 32\u2009GB inbuilt' '16\u2009GB RAM, 512\u2009GB inbuilt'
#  '2\u2009GB RAM, 64\u2009GB inbuilt' '4\u2009GB RAM, 512\u2009MB inbuilt'
#  '6\u2009GB RAM, 256\u2009GB inbuilt'
#  '12\u2009GB RAM, 128\u2009GB inbuilt'
#  '512\u2009MB RAM, 4\u2009GB inbuilt'
#  '18\u2009GB RAM, 512\u2009GB inbuilt' '6\u2009GB RAM, 1\u2009TB inbuilt'
#  '12\u2009GB RAM, 512\u2009GB inbuilt'
#  '4\u2009GB RAM, 256\u2009GB inbuilt' 'Unisoc T107'
#  '1\u2009GB RAM, 16\u2009GB inbuilt' '18\u2009GB RAM, 256\u2009GB inbuilt'
#  '64\u2009GB inbuilt' '128\u2009MB RAM, 48\u2009MB inbuilt'
#  '512\u2009GB inbuilt' 'Single Core, 208\u2009MHz Processor'
#  '64\u2009MB RAM, 128\u2009MB inbuilt' 'T117'
#  '4\u2009MB RAM, 4\u2009MB inbuilt' '3\u2009GB RAM, 16\u2009GB inbuilt'
#  '1\u2009GB RAM, 8\u2009GB inbuilt' '1325\u2009mAh Battery'
#  'Dual Core, 500\u2009MHz Processor' '6\u2009GB RAM, 512\u2009GB inbuilt'
#  '800\u2009mAh Battery' '3.6 inches, 240\u2009x\u2009320\u2009px Display'
#  '1750\u2009mAh Battery' '200\u2009mAh Battery' '1200\u2009mAh Battery'
#  '8\u2009MB RAM, 16\u2009MB inbuilt'
#  '1.5 inches, 120\u2009x\u2009120\u2009px Display'
#  '8\u2009GB RAM, 512\u2009GB inbuilt' '2\u2009GB RAM, 16\u2009GB inbuilt'
#  '2.4 inches, 240\u2009x\u2009320\u2009px Display'
#  '4 inches, 640\u2009x\u20091136\u2009px Display' '1000\u2009mAh Battery'
#  '32\u2009MB RAM, 32\u2009MB inbuilt' '4\u2009GB RAM, 512\u2009GB inbuilt'
#  '1470\u2009mAh Battery' '48\u2009MB RAM, 48\u2009MB inbuilt'
#  '4\u2009MB inbuilt' '1800\u2009mAh Battery'
#  '16\u2009MB RAM, 16\u2009MB inbuilt' '12\u2009GB RAM, 1\u2009TB inbuilt'
#  'No Wifi']
# battery:
#
# ['5000\u2009mAh Battery with 100W Fast Charging'
#  '5000\u2009mAh Battery with 33W Fast Charging'
#  '5000\u2009mAh Battery with 15W Fast Charging'
#  '5000\u2009mAh Battery with Fast Charging'
#  '5000\u2009mAh Battery with 67W Fast Charging'
#  '5000\u2009mAh Battery with 25W Fast Charging'
#  '3279\u2009mAh Battery with Fast Charging'
#  '4980\u2009mAh Battery with 120W Fast Charging'
#  '4500\u2009mAh Battery with 33W Fast Charging'
#  '4500\u2009mAh Battery with 80W Fast Charging'
#  '5000\u2009mAh Battery with 18W Fast Charging'
#  '5000\u2009mAh Battery with 45W Fast Charging'
#  '3240\u2009mAh Battery with Fast Charging'
#  '5000\u2009mAh Battery with 10W Fast Charging'
#  '4700\u2009mAh Battery with 80W Fast Charging'
#  '5000\u2009mAh Battery with 80W Fast Charging'
#  '4830\u2009mAh Battery with 66W Fast Charging'
#  '4800\u2009mAh Battery with 100W Fast Charging'
#  '4500\u2009mAh Battery with Fast Charging'
#  '4323\u2009mAh Battery with Fast Charging'
#  '4500\u2009mAh Battery with 44W Fast Charging'
#  '4500\u2009mAh Battery with 100W Fast Charging'
#  '4700\u2009mAh Battery with 67W Fast Charging' '3110\u2009mAh Battery'
#  '4500\u2009mAh Battery with 25W Fast Charging'
#  '5000\u2009mAh Battery with 66W Fast Charging'
#  '5200\u2009mAh Battery with 210W Fast Charging'
#  '4500\u2009mAh Battery with 67W Fast Charging'
#  '5000\u2009mAh Battery with 30W Fast Charging'
#  '5000\u2009mAh Battery with 44W Fast Charging'
#  '6000\u2009mAh Battery with 25W Fast Charging' '5000\u2009mAh Battery'
#  '5000\u2009mAh Battery with 120W Fast Charging'
#  '4325\u2009mAh Battery with Fast Charging'
#  '4700\u2009mAh Battery with 45W Fast Charging'
#  '4600\u2009mAh Battery with 66W Fast Charging'
#  '4200\u2009mAh Battery with 44W Fast Charging'
#  '4800\u2009mAh Battery with 150W Fast Charging' '3500\u2009mAh Battery'
#  '3095\u2009mAh Battery with Fast Charging'
#  '4800\u2009mAh Battery with 67W Fast Charging'
#  '4020\u2009mAh Battery with 33W Fast Charging'
#  '3200\u2009mAh Battery with Fast Charging'
#  '5200\u2009mAh Battery with 33W Fast Charging'
#  '4400\u2009mAh Battery with 68W Fast Charging'
#  '4310\u2009mAh Battery with 50W Fast Charging'
#  '4820\u2009mAh Battery with 120W Fast Charging'
#  '3700\u2009mAh Battery with 25W Fast Charging'
#  '5160\u2009mAh Battery with 45W Fast Charging'
#  '6.1 inches, 1170\u2009x\u20092532\u2009px Display with Large Notch'
#  '5080\u2009mAh Battery with 67W Fast Charging'
#  '4700\u2009mAh Battery with 66W Fast Charging'
#  '3900\u2009mAh Battery with 25W Fast Charging'
#  '4800\u2009mAh Battery with 68W Fast Charging'
#  '4410\u2009mAh Battery with Fast Charging'
#  '5000\u2009mAh Battery with 20W Fast Charging'
#  '5020\u2009mAh Battery with 18W Fast Charging' '2800\u2009mAh Battery'
#  '6000\u2009mAh Battery with 18W Fast Charging'
#  '4400\u2009mAh Battery with 66W Fast Charging'
#  '5.4 inches, 1080\u2009x\u20092340\u2009px Display'
#  '4352\u2009mAh Battery with 25W Fast Charging' '1450\u2009mAh Battery'
#  '5000\u2009mAh Battery with 65W Fast Charging'
#  '4520\u2009mAh Battery with 67W Fast Charging'
#  '4352\u2009mAh Battery with Fast Charging'
#  '4810\u2009mAh Battery with 120W Fast Charging'
#  '6000\u2009mAh Battery with 15W Fast Charging'
#  '4500\u2009mAh Battery with 66W Fast Charging' '4000\u2009mAh Battery'
#  '5200\u2009mAh Battery with 67W Fast Charging'
#  '2050\u2009mAh Battery with Fast Charging'
#  '4500\u2009mAh Battery with 180W Fast Charging'
#  '4600\u2009mAh Battery with 125W Fast Charging'
#  '4200\u2009mAh Battery with 120W Fast Charging' '2150\u2009mAh Battery'
#  '6000\u2009mAh Battery with 65W Fast Charging'
#  '4610\u2009mAh Battery with 125W Fast Charging'
#  '5100\u2009mAh Battery with 40W Fast Charging'
#  '7000\u2009mAh Battery with 33W Fast Charging'
#  '4300\u2009mAh Battery with 44W Fast Charging'
#  '5500\u2009mAh Battery with 67W Fast Charging'
#  '4500\u2009mAh Battery with 60W Fast Charging'
#  '4700\u2009mAh Battery with 200W Fast Charging'
#  '4050\u2009mAh Battery with 44W Fast Charging'
#  '4300\u2009mAh Battery with 120W Fast Charging'
#  '4355\u2009mAh Battery with 30W Fast Charging'
#  '6000\u2009mAh Battery with 80W Fast Charging'
#  '4500\u2009mAh Battery with 45W Fast Charging'
#  '4200\u2009mAh Battery with 33W Fast Charging'
#  '3060\u2009mAh Battery with Fast Charging'
#  '4500\u2009mAh Battery with 65W Fast Charging' '1500\u2009mAh Battery'
#  '5003\u2009mAh Battery with 30W Fast Charging'
#  '4600\u2009mAh Battery with 120W Fast Charging'
#  '2438\u2009mAh Battery with Fast Charging'
#  '3500\u2009mAh Battery with Fast Charging'
#  '4250\u2009mAh Battery with 33W Fast Charging'
#  '3300\u2009mAh Battery with 15W Fast Charging'
#  '4800\u2009mAh Battery with 66W Fast Charging'
#  '4400\u2009mAh Battery with 25W Fast Charging' '4450\u2009mAh Battery'
#  '4614\u2009mAh Battery with 30W Fast Charging'
#  '5020\u2009mAh Battery with 33W Fast Charging'
#  '6000\u2009mAh Battery with 20W Fast Charging'
#  '4700\u2009mAh Battery with 120W Fast Charging'
#  '4870\u2009mAh Battery with 120W Fast Charging' '4030\u2009mAh Battery'
#  '4350\u2009mAh Battery with 120W Fast Charging'
#  '5100\u2009mAh Battery with 45W Fast Charging'
#  '4500\u2009mAh Battery with 30W Fast Charging'
#  '4300\u2009mAh Battery with 33W Fast Charging'
#  '6000\u2009mAh Battery with 33W Fast Charging'
#  '2800\u2009mAh Battery with Fast Charging'
#  '4100\u2009mAh Battery with 15W Fast Charging'
#  '48\u2009MB RAM, 128\u2009MB inbuilt'
#  '4200\u2009mAh Battery with 66W Fast Charging'
#  '4000\u2009mAh Battery with 25W Fast Charging'
#  '21000\u2009mAh Battery with 33W Fast Charging' '2000\u2009mAh Battery'
#  '4600\u2009mAh Battery with 240W Fast Charging'
#  '4700\u2009mAh Battery with Fast Charging'
#  '5160\u2009mAh Battery with 67W Fast Charging'
#  '6000\u2009mAh Battery with 120W Fast Charging'
#  '4520\u2009mAh Battery with 33W Fast Charging'
#  '4300\u2009mAh Battery with 65W Fast Charging'
#  '4200\u2009mAh Battery with 65W Fast Charging'
#  '4450\u2009mAh Battery with 125W Fast Charging'
#  '4860\u2009mAh Battery with 67W Fast Charging' '2275\u2009mAh Battery'
#  '4230\u2009mAh Battery'
#  '4.7 inches, 750\u2009x\u20091334\u2009px Display'
#  '5160\u2009mAh Battery with 33W Fast Charging'
#  '6.06 inches, 1170\u2009x\u20092532\u2009px, 120 Hz Display with Punch Hole'
#  '5000\u2009mAh Battery with 19W Fast Charging'
#  '4700\u2009mAh Battery with 33W Fast Charging'
#  '4300\u2009mAh Battery with 30W Fast Charging'
#  '4000\u2009mAh Battery with Fast Charging' '6000\u2009mAh Battery'
#  '4050\u2009mAh Battery with 40W Fast Charging' '1020\u2009mAh Battery'
#  '1900\u2009mAh Battery' '3020\u2009mAh Battery'
#  '4730\u2009mAh Battery with 80W Fast Charging'
#  '4000\u2009mAh Battery with 21W Fast Charging'
#  '6000\u2009mAh Battery with 45W Fast Charging'
#  '5000\u2009mAh Battery with 135W Fast Charging'
#  '4300\u2009mAh Battery with 66W Fast Charging' '3300\u2009mAh Battery'
#  '3520\u2009mAh Battery with Fast Charging'
#  '5000\u2009mAh Battery with 60W Fast Charging'
#  '4080\u2009mAh Battery with 18W Fast Charging'
#  '4300\u2009mAh Battery with 210W Fast Charging'
#  '4000\u2009mAh Battery with 33W Fast Charging' '800\u2009mAh Battery'
#  '2500\u2009mAh Battery' '5050\u2009mAh Battery with 10W Fast Charging'
#  '4000\u2009mAh Battery with 66W Fast Charging'
#  '5600\u2009mAh Battery with 68W Fast Charging'
#  '4470\u2009mAh Battery with 18W Fast Charging'
#  '6000\u2009mAh Battery with 44W Fast Charging'
#  '64\u2009MB RAM, 128\u2009MB inbuilt'
#  '5000\u2009mAh Battery with 165W Fast Charging' '3360\u2009mAh Battery'
#  '4500\u2009mAh Battery with 20W Fast Charging'
#  '4800\u2009mAh Battery with 125W Fast Charging'
#  '5050\u2009mAh Battery with 18W Fast Charging'
#  '4500\u2009mAh Battery with 120W Fast Charging' '3000\u2009mAh Battery'
#  '4000\u2009mAh Battery with 18W Fast Charging'
#  '3500\u2009mAh Battery with 18W Fast Charging' '2230\u2009mAh Battery'
#  '4 inches, 720\u2009x\u20091280\u2009px Display'
#  '32\u2009MB RAM, 32\u2009MB inbuilt'
#  '9800\u2009mAh Battery with 66W Fast Charging' '1150\u2009mAh Battery'
#  '4300\u2009mAh Battery with 25W Fast Charging'
#  '1.77 inches, 128\u2009x\u2009160\u2009px Display'
#  '5\u2009MP Rear & 5\u2009MP Front Camera'
#  '1.8 inches, 160\u2009x\u2009128\u2009px Display'
#  '4500\u2009mAh Battery with 50W Fast Charging'
#  '1821\u2009mAh Battery with 18W Fast Charging'
#  '0.49 inches, 64\u2009x\u200932\u2009px Display'
#  '4000\u2009mAh Battery with 10W Fast Charging'
#  '4800\u2009mAh Battery with 33W Fast Charging'
#  '4300\u2009mAh Battery with Fast Charging' '1480\u2009mAh Battery'
#  '5100\u2009mAh Battery with 120W Fast Charging'
#  '4000\u2009mAh Battery with 15W Fast Charging' 'No Rear Camera'
#  '4300\u2009mAh Battery with 67W Fast Charging'
#  '4310\u2009mAh Battery with 30W Fast Charging'
#  '4000\u2009mAh Battery with 45W Fast Charging'
#  '4015\u2009mAh Battery with 30W Fast Charging'
#  '4300\u2009mAh Battery with 45W Fast Charging'
#  '4500\u2009mAh Battery with 18W Fast Charging'
#  '4020\u2009mAh Battery with 68W Fast Charging'
#  '3285\u2009mAh Battery with Fast Charging'
#  '4360\u2009mAh Battery with 66W Fast Charging'
#  '0.3\u2009MP Rear & 0.3\u2009MP Front Camera'
#  '4000\u2009mAh Battery with 30W Fast Charging'
#  '4000\u2009mAh Battery with 20W Fast Charging'
#  '8\u2009MP Rear & 1.2\u2009MP Front Camera'
#  '1.8 inches, 128\u2009x\u2009160\u2009px Display'
#  '6.1 inches, 750\u2009x\u20091580\u2009px Display'
#  '4830\u2009mAh Battery with 67W Fast Charging'
#  '4200\u2009mAh Battery with 67W Fast Charging'
#  '4000\u2009mAh Battery with 22.5W Fast Charging'
#  '5020\u2009mAh Battery with 67W Fast Charging'
#  '4800\u2009mAh Battery with 25W Fast Charging'
#  '4200\u2009mAh Battery with 40W Fast Charging'
#  '3700\u2009mAh Battery with Fast Charging' '3315\u2009mAh Battery'
#  '5080\u2009mAh Battery with 120W Fast Charging'
#  '5100\u2009mAh Battery with 18W Fast Charging' '5050\u2009mAh Battery'
#  '6000\u2009mAh Battery with Fast Charging' '1000\u2009mAh Battery'
#  '4800\u2009mAh Battery' '7000\u2009mAh Battery with Fast Charging'
#  '2.8 inches, 240\u2009x\u2009320\u2009px Display'
#  '3600\u2009mAh Battery with 18W Fast Charging'
#  '5020\u2009mAh Battery with 22.5W Fast Charging'
#  '3700\u2009mAh Battery with 18W Fast Charging'
#  '3100\u2009mAh Battery with 15W Fast Charging' '4100\u2009mAh Battery'
#  '22000\u2009mAh Battery with 33W Fast Charging'
#  '5000\u2009mAh Battery with 22.5W Fast Charging' '7000\u2009mAh Battery'
#  '5000\u2009mAh Battery with 40W Fast Charging'
#  '4500\u2009mAh Battery with 150W Fast Charging'
#  '7000\u2009mAh Battery with 18W Fast Charging' '2400\u2009mAh Battery'
#  '4350\u2009mAh Battery with 65W Fast Charging'
#  '4000\u2009mAh Battery with 27W Fast Charging' '3200\u2009mAh Battery'
#  '2.4 inches, 240\u2009x\u2009320\u2009px Display'
#  '1.5 inches, 128\u2009x\u2009128\u2009px Display'
#  '4532\u2009mAh Battery with Fast Charging'
#  '2.4 inches, 240\u2009x\u2009360\u2009px Display'
#  '4200\u2009mAh Battery with 55W Fast Charging'
#  '3000\u2009mAh Battery with 10W Fast Charging'
#  '5050\u2009mAh Battery with 30W Fast Charging'
#  '5065\u2009mAh Battery with 67W Fast Charging'
#  '4620\u2009mAh Battery with 18W Fast Charging'
#  '4100\u2009mAh Battery with 33W Fast Charging'
#  '4780\u2009mAh Battery with 30W Fast Charging'
#  '3730\u2009mAh Battery with Fast Charging'
#  '4500\u2009mAh Battery with 55W Fast Charging'
#  '3400\u2009mAh Battery with Fast Charging' '2730\u2009mAh Battery'
#  '5180\u2009mAh Battery with 10W Fast Charging'
#  '4500\u2009mAh Battery with 68W Fast Charging' '8000\u2009mAh Battery'
#  '5000\u2009mAh Battery with 68W Fast Charging'
#  '5000\u2009mAh Battery with 68.2W Fast Charging']
# display:
#
# ['6.7 inches, 1440\u2009x\u20093216\u2009px, 120 Hz Display with Punch Hole'
#  '6.59 inches, 1080\u2009x\u20092412\u2009px, 120 Hz Display with Punch Hole'
#  '6.6 inches, 1080\u2009x\u20092408\u2009px, 90 Hz Display with Water Drop Notch'
#  '6.55 inches, 1080\u2009x\u20092400\u2009px, 120 Hz Display with Punch Hole'
#  '6.7 inches, 1080\u2009x\u20092412\u2009px, 120 Hz Display with Punch Hole'
#  '6.6 inches, 1080\u2009x\u20092408\u2009px, 120 Hz Display with Water Drop Notch'
#  '6.1 inches, 1170\u2009x\u20092532\u2009px Display with Small Notch'
#  '6.67 inches, 1080\u2009x\u20092400\u2009px, 120 Hz Display with Punch Hole'
#  '6.43 inches, 1080\u2009x\u20092400\u2009px, 90 Hz Display with Punch Hole'
#  '6.72 inches, 1080\u2009x\u20092400\u2009px, 120 Hz Display with Punch Hole'
#  '6.56 inches, 720\u2009x\u20091612\u2009px, 90 Hz Display with Water Drop Notch'
#  '6.58 inches, 1080\u2009x\u20092408\u2009px, 120 Hz Display with Water Drop Notch'
#  '6.8 inches, 1440\u2009x\u20093088\u2009px, 120 Hz Display with Punch Hole'
#  '6.51 inches, 720\u2009x\u20091600\u2009px Display with Water Drop Notch'
#  '6.55 inches, 720\u2009x\u20091612\u2009px Display with Water Drop Notch'
#  '6.56 inches, 1080\u2009x\u20092376\u2009px, 120 Hz Display with Punch Hole'
#  '6.7 inches, 1080\u2009x\u20092400\u2009px, 120 Hz Display with Punch Hole'
#  '6.5 inches, 1080\u2009x\u20092400\u2009px, 120 Hz Display with Punch Hole'
#  '6.7 inches, 1290\u2009x\u20092796\u2009px, 120 Hz Display'
#  '6.44 inches, 1080\u2009x\u20092408\u2009px, 90 Hz Display with Water Drop Notch'
#  '6.56 inches, 1080\u2009x\u20092400\u2009px, 120 Hz Display with Punch Hole'
#  '6.1 inches, 828\u2009x\u20091792\u2009px Display with Large Notch'
#  '6.4 inches, 1080\u2009x\u20092340\u2009px, 120 Hz Display with Punch Hole'
#  '6.8 inches, 1440\u2009x\u20093080\u2009px, 120 Hz Display with Punch Hole'
#  '6.67 inches, 1080\u2009x\u20092460\u2009px, 120 Hz Display with Punch Hole'
#  '6.67 inches, 1080\u2009x\u20092400\u2009px, 90 Hz Display with Punch Hole'
#  '6.58 inches, 1080\u2009x\u20092408\u2009px, 90 Hz Display with Water Drop Notch'
#  '6.6 inches, 1080\u2009x\u20092400\u2009px, 120 Hz Display with Water Drop Notch'
#  '6.5 inches, 720\u2009x\u20091600\u2009px Display with Water Drop Notch'
#  '6.78 inches, 1080\u2009x\u20092400\u2009px, 120 Hz Display with Punch Hole'
#  '6.5 inches, 720\u2009x\u20091600\u2009px, 90 Hz Display'
#  '6.6 inches, 1080\u2009x\u20092400\u2009px, 120 Hz Display with Punch Hole'
#  '6.4 inches, 1080\u2009x\u20092400\u2009px, 90 Hz Display with Punch Hole'
#  '6.6 inches, 1080\u2009x\u20092408\u2009px, 90 Hz Display with Punch Hole'
#  '6.7 inches, 1284\u2009x\u20092778\u2009px Display with Small Notch'
#  '6.43 inches, 1080\u2009x\u20092400\u2009px Display with Punch Hole'
#  '6.6 inches, 1080\u2009x\u20092340\u2009px, 120 Hz Display with Punch Hole'
#  '6.55 inches, 1080\u2009x\u20092400\u2009px, 90 Hz Display with Punch Hole'
#  '6.6 inches, 1080\u2009x\u20092408\u2009px Display with Water Drop Notch'
#  '6.6 inches, 1080\u2009x\u20092400\u2009px, 90 Hz Display with Punch Hole'
#  '7.1 inches, 1792\u2009x\u20091920\u2009px, 120 Hz Display with Punch Hole'
#  '6.56 inches, 720\u2009x\u20091612\u2009px Display with Water Drop Notch'
#  '6.44 inches, 1080\u2009x\u20092400\u2009px, 90 Hz Display with Small Notch'
#  '6.5 inches, 1080\u2009x\u20092400\u2009px, 90 Hz Display with Punch Hole'
#  '6.26 inches, 720\u2009x\u20091600\u2009px Display with Large Notch'
#  '6.1 inches, 1170\u2009x\u20092532\u2009px, 120 Hz Display with Large Notch'
#  '6.58 inches, 1080\u2009x\u20092400\u2009px, 120 Hz Display with Punch Hole'
#  '6.53 inches, 720\u2009x\u20091600\u2009px Display with Water Drop Notch'
#  '6.5 inches, 720\u2009x\u20091600\u2009px, 90 Hz Display with Water Drop Notch'
#  '6.5 inches, 1080\u2009x\u20092400\u2009px, 144 Hz Display with Punch Hole'
#  '6.78 inches, 1440\u2009x\u20093200\u2009px, 120 Hz Display with Punch Hole'
#  '6.6 inches, 1080\u2009x\u20092412\u2009px, 90 Hz Display with Punch Hole'
#  '6.78 inches, 1440\u2009x\u20093200\u2009px, 144 Hz Display with Punch Hole'
#  '8.03 inches, 1916\u2009x\u20092160\u2009px, 120 Hz Display'
#  '6.1 inches, 1179\u2009x\u20092556\u2009px, 120 Hz Display'
#  '6.55 inches, 1080\u2009x\u20092460\u2009px, 144 Hz Display with Punch Hole'
#  '6.73 inches, 1440\u2009x\u20093200\u2009px, 120 Hz Display with Punch Hole'
#  '6.73 inches, 1080\u2009x\u20092400\u2009px, 144 Hz Display with Punch Hole'
#  '6.1 inches, 1080\u2009x\u20092340\u2009px, 120 Hz Display with Punch Hole'
#  '6.44 inches, 1080\u2009x\u20092408\u2009px Display with Water Drop Notch'
#  '6.8 inches, 1080\u2009x\u20092400\u2009px, 120 Hz Display with Punch Hole'
#  '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera'
#  '6.6 inches, 1080\u2009x\u20092460\u2009px, 144 Hz Display with Punch Hole'
#  '6.52 inches, 720\u2009x\u20091600\u2009px Display with Water Drop Notch'
#  '6.44 inches, 1080\u2009x\u20092404\u2009px, 90 Hz Display with Water Drop Notch'
#  '6.73 inches, 1080\u2009x\u20092448\u2009px, 165 Hz Display'
#  '6.7 inches, 1080\u2009x\u20092400\u2009px, 144 Hz Display with Punch Hole'
#  '6.14 inches, 1080\u2009x\u20092400\u2009px Display with Punch Hole'
#  '6.7 inches, 1080\u2009x\u20092400\u2009px Display with Punch Hole'
#  '6.47 inches, 1080\u2009x\u20092400\u2009px Display with Punch Hole'
#  '6.1 inches, 1080\u2009x\u20092400\u2009px, 90 Hz Display with Punch Hole'
#  '6.67 inches, 1080\u2009x\u20092400\u2009px Display with Punch Hole'
#  '6.5 inches, 720\u2009x\u20091600\u2009px, 90 Hz Display with Punch Hole'
#  '6.59 inches, 1080\u2009x\u20092412\u2009px, 90 Hz Display with Punch Hole'
#  '6.62 inches, 1080\u2009x\u20092400\u2009px, 120 Hz Display with Punch Hole'
#  '5 inches, 720\u2009x\u20091280\u2009px Display'
#  '6.52 inches, 720\u2009x\u20091560\u2009px Display with Punch Hole'
#  '6.7 inches, 720\u2009x\u20091600\u2009px Display with Water Drop Notch'
#  '6.6 inches, 2460\u2009x\u20091080\u2009px, 90 Hz Display with Punch Hole'
#  '6.68 inches, 1284\u2009x\u20092778\u2009px, 120 Hz Display with Punch Hole'
#  '6.7 inches, 1080\u2009x\u20092412\u2009px, 120 Hz Display with Water Drop Notch'
#  '6.78 inches, 1080\u2009x\u20092460\u2009px, 120 Hz Display with Punch Hole'
#  '2.7 inches, 240\u2009x\u2009320\u2009px Display'
#  '6.4 inches, 1080\u2009x\u20092400\u2009px, 120 Hz Display with Punch Hole'
#  '6.7 inches, 1284\u2009x\u20092778\u2009px, 120 Hz Display with Small Notch'
#  '6.73 inches, 1080\u2009x\u20092412\u2009px, 120 Hz Display with Punch Hole'
#  '6.78 inches, 1260\u2009x\u20092800\u2009px, 120 Hz Display with Punch Hole'
#  '6.6 inches, 2408\u2009x\u20091080\u2009px Display with Water Drop Notch'
#  '6.54 inches, 720\u2009x\u20091560\u2009px Display with Small Notch'
#  '4.7 inches, 750\u2009x\u20091334\u2009px Display with Large Notch'
#  '6.6 inches, 1080\u2009x\u20092412\u2009px, 120 Hz Display with Punch Hole'
#  '6.58 inches, 1080\u2009x\u20092408\u2009px Display with Water Drop Notch'
#  '6.56 inches, 720\u2009x\u20091600\u2009px Display with Water Drop Notch'
#  '6.7 inches, 1080\u2009x\u20092400\u2009px, 165 Hz Display'
#  '6.5 inches, 720\u2009x\u20091600\u2009px Display with Small Notch'
#  '6.1 inches, 720\u2009x\u20091560\u2009px Display with Water Drop Notch'
#  '3.54 inches, 640\u2009x\u2009960\u2009px Display'
#  '6.67 inches, 1080\u2009x\u20092412\u2009px, 90 Hz Display with Punch Hole'
#  '6.9 inches, 1400\u2009x\u20093200\u2009px, 120 Hz Display with Punch Hole'
#  '6.55 inches, 1080\u2009x\u20092400\u2009px, 144 Hz Display with Punch Hole'
#  '6.56 inches, 720\u2009x\u20091600\u2009px, 90 Hz Display with Water Drop Notch'
#  '6.67 inches, 1080\u2009x\u20092400\u2009px, 144 Hz Display with Punch Hole'
#  '6.6 inches, 1440\u2009x\u20093200\u2009px, 120 Hz Display with Punch Hole'
#  '6.58 inches, 1080\u2009x\u20092400\u2009px, 90 Hz Display with Water Drop Notch'
#  '6.82 inches, 720\u2009x\u20091600\u2009px, 90 Hz Display with Water Drop Notch'
#  '6.5 inches, 1600\u2009x\u2009720\u2009px, 90 Hz Display with Water Drop Notch'
#  '6.7 inches, 1440\u2009x\u20093120\u2009px, 120 Hz Display with Punch Hole'
#  '6.95 inches, 1080\u2009x\u20092460\u2009px, 90 Hz Display with Punch Hole'
#  '6.56 inches, 1080\u2009x\u20092376\u2009px, 90 Hz Display with Small Notch'
#  '6.67 inches, 1440\u2009x\u20093200\u2009px, 120 Hz Display with Punch Hole'
#  '6.7 inches, 720\u2009x\u20091650\u2009px Display with Punch Hole'
#  '8.02 inches, 1914\u2009x\u20092160\u2009px, 120 Hz Display with Punch Hole'
#  '6.44 inches, 1080\u2009x\u20092400\u2009px Display with Water Drop Notch'
#  '6.3 inches, 1080\u2009x\u20092400\u2009px, 90 Hz Display with Punch Hole'
#  '6.8 inches, 1116\u2009x\u20092480\u2009px, 120 Hz Display'
#  '6.7 inches, 1080\u2009x\u20092400\u2009px, 90 Hz Display with Water Drop Notch'
#  '6.9 inches, 1080\u2009x\u20092460\u2009px, 120 Hz Display with Punch Hole'
#  '6.1 inches, 828\u2009x\u20091792\u2009px Display'
#  '6.7 inches, 1080\u2009x\u20092400\u2009px Display with Water Drop Notch'
#  '6.4 inches, 1080\u2009x\u20092400\u2009px, 90 Hz Display with Water Drop Notch'
#  '2.8 inches, 240\u2009x\u2009320\u2009px Display'
#  '6.71 inches, 1440\u2009x\u20093120\u2009px, 120 Hz Display with Punch Hole'
#  '5.4 inches, 1080\u2009x\u20092340\u2009px Display with Large Notch'
#  '6.9 inches, 1080\u2009x\u20092460\u2009px, 90 Hz Display with Punch Hole'
#  '6.78 inches, 1080\u2009x\u20092448\u2009px, 165 Hz Display'
#  '5.42 inches, 1080\u2009x\u20092340\u2009px Display with Punch Hole'
#  '6.6 inches, 1080\u2009x\u20092400\u2009px Display with Water Drop Notch'
#  '6.36 inches, 1080\u2009x\u20092400\u2009px, 120 Hz Display with Punch Hole'
#  '6.7 inches, 1080\u2009x\u20092640\u2009px, 120 Hz Display with Punch Hole'
#  '6.4 inches, 1080\u2009x\u20092400\u2009px Display with Punch Hole'
#  '6.6 inches, 1600\u2009x\u2009720\u2009px Display with Punch Hole'
#  '6 inches, 1080\u2009x\u20092400\u2009px, 120 Hz Display with Punch Hole'
#  '6.81 inches, 1080\u2009x\u20092388\u2009px Display'
#  '7.6 inches, 1812\u2009x\u20092176\u2009px, 120 Hz Display with Punch Hole'
#  '7.8 inches, 1440\u2009x\u20091920\u2009px Display'
#  '6.6 inches, 720\u2009x\u20091600\u2009px, 90 Hz Display with Water Drop Notch'
#  '6.8 inches, 1440\u2009x\u20093200\u2009px, 120 Hz Display with Punch Hole'
#  '6.82 inches, 720\u2009x\u20091640\u2009px, 90 Hz Display with Punch Hole'
#  '6.6 inches, 1080\u2009x\u20092412\u2009px, 144 Hz Display with Punch Hole'
#  '6.7 inches, 2400\u2009x\u20091080\u2009px Display with Punch Hole'
#  '6.8 inches, 1080\u2009x\u20092460\u2009px, 120 Hz Display with Punch Hole'
#  '6.5 inches, 720\u2009x\u20091600\u2009px, 120 Hz Display with Punch Hole'
#  '6.53 inches, 720\u2009x\u20091600\u2009px, 90 Hz Display with Punch Hole'
#  '5.45 inches, 720\u2009x\u20091440\u2009px Display'
#  '6.2 inches, 1520\u2009x\u2009720\u2009px Display with Water Drop Notch'
#  '6.55 inches, 1612\u2009x\u2009720\u2009px, 90 Hz Display with Water Drop Notch'
#  '6.67 inches, 1220\u2009x\u20092712\u2009px, 120 Hz Display with Punch Hole'
#  '6.83 inches, 1200\u2009x\u20092860\u2009px, 144 Hz Display with Punch Hole'
#  '6.8 inches, 1200\u2009x\u20092400\u2009px, 120 Hz Display with Punch Hole'
#  '6.5 inches, 1644\u2009x\u20093840\u2009px, 120 Hz Display'
#  '6.44 inches, 1080\u2009x\u20092400\u2009px Display with Small Notch'
#  '5.7 inches, 1080\u2009x\u20092280\u2009px Display'
#  '6.4 inches, 1440\u2009x\u20093040\u2009px Display with Punch Hole'
#  '1450\u2009mAh Battery'
#  '6.2 inches, 1080\u2009x\u20092400\u2009px, 120 Hz Display with Punch Hole'
#  '6.5 inches, 720\u2009x\u20091560\u2009px Display with Small Notch'
#  '6.6 inches, 720\u2009x\u20091612\u2009px, 90 Hz Display with Water Drop Notch'
#  '6.8 inches, 1080\u2009x\u20092520\u2009px, 120 Hz Display with Punch Hole'
#  '6.78 inches, 1080\u2009x\u20092400\u2009px Display with Punch Hole'
#  '6.5 inches, 1600\u2009x\u2009720\u2009px Display with Water Drop Notch'
#  '2.4 inches, 320\u2009x\u2009240\u2009px Display'
#  '6.73 inches, 1290\u2009x\u20092796\u2009px, 120 Hz Display'
#  '6.71 inches, 1440\u2009x\u20093214\u2009px, 120 Hz Display with Punch Hole'
#  '6.67 inches, 2400\u2009x\u20091080\u2009px, 120 Hz Display with Punch Hole'
#  '6.8 inches, 1080\u2009x\u20092448\u2009px, 165 Hz Display'
#  '6.5 inches, 720\u2009x\u20091560\u2009px Display with Water Drop Notch'
#  '6.49 inches, 1080\u2009x\u20092400\u2009px, 90 Hz Display with Punch Hole'
#  '6.44 inches, 1080\u2009x\u20092400\u2009px, 90 Hz Display with Dual Punch Hole'
#  '6.51 inches, 720\u2009x\u20091600\u2009px Display with Punch Hole'
#  '6.81 inches, 1080\u2009x\u20092400\u2009px Display with Punch Hole'
#  '4.7 inches, 1080\u2009x\u20091920\u2009px Display'
#  '6.8 inches, 1080\u2009x\u20092460\u2009px Display'
#  '12\u2009MP Rear & 7\u2009MP Front Camera'
#  '6.6 inches, 720\u2009x\u20091600\u2009px Display with Water Drop Notch'
#  '50\u2009MP + 12\u2009MP + 12\u2009MP Triple Rear & 12\u2009MP Front Camera'
#  '6.82 inches, 720\u2009x\u20091640\u2009px, 90 Hz Display with Water Drop Notch'
#  '6.7 inches, 1080\u2009x\u20092340\u2009px, 90 Hz Display with Punch Hole'
#  '6.71 inches, 720\u2009x\u20091650\u2009px Display with Water Drop Notch'
#  '5.9 inches, 1080\u2009x\u20092400\u2009px, 120 Hz Display with Punch Hole'
#  '6.2 inches, 720\u2009x\u20091680\u2009px Display'
#  '6.8 inches, 1080\u2009x\u20092460\u2009px Display with Punch Hole'
#  '6.4 inches, 720\u2009x\u20091600\u2009px, 90 Hz Display with Water Drop Notch'
#  '7.92 inches, 2088\u2009x\u20092250\u2009px Display'
#  '6.52 inches, 720\u2009x\u20091600\u2009px, 90 Hz Display with Water Drop Notch'
#  '6.82 inches, 1640\u2009x\u2009720\u2009px, 90 Hz Display with Punch Hole'
#  '1.8 inches, 120\u2009x\u2009160\u2009px Display'
#  '6.71 inches, 1440\u2009x\u20093200\u2009px, 120 Hz Display with Punch Hole'
#  '6.18 inches, 1080\u2009x\u20092246\u2009px Display with Large Notch'
#  '4.5 inches, 480\u2009x\u2009854\u2009px Display'
#  '5.5 inches, 1080\u2009x\u20091920\u2009px Display'
#  '6.5 inches, 720\u2009x\u20091600\u2009px Display with Punch Hole'
#  '5 inches, 854\u2009x\u2009480\u2009px Display'
#  '8.03 inches, 1916\u2009x\u20092160\u2009px, 120 Hz Display with Punch Hole'
#  '6.74 inches, 1212\u2009x\u20092616\u2009px, 120 Hz Display'
#  '6.44 inches, 1080\u2009x\u20092400\u2009px, 120 Hz Display with Water Drop Notch'
#  '6.1 inches, 1080\u2009x\u20092520\u2009px, 120 Hz Display'
#  '6.35 inches, 720\u2009x\u20091544\u2009px Display with Water Drop Notch'
#  '6.66 inches, 720\u2009x\u20091600\u2009px, 90 Hz Display with Water Drop Notch'
#  '6.67 inches, 1080\u2009x\u20092160\u2009px, 90 Hz Display with Punch Hole'
#  '6.8 inches, 1080\u2009x\u20092400\u2009px, 120 Hz Display'
# ...
#  '108\u2009MP + 13\u2009MP + 2\u2009MP Triple Rear & 60\u2009MP Front Camera'
#  '50\u2009MP + 5\u2009MP + 2\u2009MP Triple Rear & 16\u2009MP Front Camera'
#  '50\u2009MP + 2\u2009MP Triple Rear & 16\u2009MP Front Camera'
#  '12\u2009MP + 5\u2009MP Dual Rear & 7\u2009MP Front Camera'
#  '108\u2009MP Quad Rear & 16\u2009MP Front Camera'
#  '64\u2009MP Quad Rear & 20\u2009MP Front Camera'
#  '50\u2009MP + 48\u2009MP + 12\u2009MP Triple Rear & 11.1\u2009MP Front Camera'
#  '50\u2009MP + 13\u2009MP + 5\u2009MP Triple Rear & 12\u2009MP Front Camera'
#  '108\u2009MP + 2\u2009MP Triple Rear & 16\u2009MP Front Camera'
#  '50\u2009MP + 12\u2009MP + 10\u2009MP Triple Rear & 32\u2009MP Front Camera'
#  '64\u2009MP + 8\u2009MP + 5\u2009MP Triple Rear & 20\u2009MP Front Camera'
#  '50\u2009MP + 16\u2009MP + 2\u2009MP Triple Rear & 16\u2009MP Front Camera'
#  '8\u2009MP + 2\u2009MP + 0.3\u2009MP Triple Rear & 8\u2009MP Front Camera'
#  '50\u2009MP + 8\u2009MP + 2\u2009MP Triple Rear & 50\u2009MP + 8\u2009MP Dual Front Camera'
#  '13\u2009MP Dual Rear & 8\u2009MP Front Camera'
#  '50\u2009MP + 12\u2009MP Dual Rear & 8\u2009MP Front Camera'
#  '64\u2009MP Quad Rear & 16\u2009MP Front Camera'
#  '64\u2009MP + 8\u2009MP + 2\u2009MP Triple Rear & 20\u2009MP Front Camera'
#  '50.3\u2009MP + 50\u2009MP + 12\u2009MP Triple Rear & 32\u2009MP Front Camera'
#  '50\u2009MP Quad Rear & 16\u2009MP Front Camera'
#  '54\u2009MP + 8\u2009MP + 2\u2009MP Triple Rear & 16\u2009MP Front Camera'
#  '200\u2009MP + 8\u2009MP + 2\u2009MP Triple Rear & 20\u2009MP Front Camera'
#  '48\u2009MP + 13\u2009MP + 13\u2009MP Triple Rear & 16\u2009MP Front Camera'
#  '200\u2009MP Quad Rear & 60\u2009MP Front Camera'
#  '12\u2009MP + 12\u2009MP + 12\u2009MP Triple Rear & 8\u2009MP Front Camera'
#  '64\u2009MP Quad Rear & 44\u2009MP + 8\u2009MP Dual Front Camera'
#  '16\u2009MP + 12.2\u2009MP Dual Rear & 8\u2009MP + TOF 3D Dual Front Camera'
#  '16\u2009MP + 12\u2009MP + 12\u2009MP Triple Rear & 10\u2009MP + 8\u2009MP Dual Front Camera'
#  '2.8 inches, 240\u2009x\u2009320\u2009px Display'
#  '64\u2009MP + 12\u2009MP + 12\u2009MP Triple Rear & 10\u2009MP Front Camera'
#  '13\u2009MP + Depth Sensor + Ultra Wide Triple Rear & 8\u2009MP Front Camera'
#  '50\u2009MP + 2\u2009MP + 2\u2009MP Triple Rear & 5\u2009MP Front Camera'
#  '64\u2009MP + 20\u2009MP + 2\u2009MP Triple Rear & 16\u2009MP Front Camera'
#  '8\u2009MP + 0.3\u2009MP Dual Rear & 8\u2009MP Front Camera'
#  '2\u2009MP Rear & 0.3\u2009MP Front Camera'
#  '200\u2009MP + 12\u2009MP + 12\u2009MP Triple Rear & 10\u2009MP Front Camera'
#  '50\u2009MP Quad Rear & 32\u2009MP Front Camera'
#  '64\u2009MP + 16\u2009MP + 8\u2009MP Triple Rear & 32\u2009MP Front Camera'
#  '48\u2009MP + 2\u2009MP Dual Rear & 5\u2009MP Front Camera'
#  '13\u2009MP + 2\u2009MP + 2\u2009MP Triple Rear & 16\u2009MP Front Camera'
#  '48\u2009MP + 8\u2009MP + 5\u2009MP Triple Rear & 20\u2009MP Front Camera'
#  '64\u2009MP Quad Rear & 32\u2009MP + 8\u2009MP Dual Front Camera'
#  '50\u2009MP + 48\u2009MP + 48\u2009MP Triple Rear & 32\u2009MP Front Camera'
#  '54\u2009MP + 50\u2009MP + 2\u2009MP Triple Rear & 32\u2009MP Front Camera'
#  '108\u2009MP + 8\u2009MP + 5\u2009MP Triple Rear & 16\u2009MP Front Camera'
#  '13\u2009MP Rear & 2.1\u2009MP Front Camera'
#  '64\u2009MP + 50\u2009MP + 2\u2009MP Triple Rear & 32\u2009MP Front Camera'
#  '64\u2009MP + 8\u2009MP + 5\u2009MP Triple Rear & 32\u2009MP Front Camera'
#  '48\u2009MP Quad Rear & 20\u2009MP Front Camera'
#  '50\u2009MP + 13\u2009MP + 8\u2009MP Triple Rear & 48\u2009MP + 8\u2009MP Dual Front Camera'
#  '50\u2009MP + Depth Sensor Dual Rear & 5\u2009MP Front Camera'
#  '50\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera'
#  '13\u2009MP + 5\u2009MP + 2\u2009MP Triple Rear & 8\u2009MP Front Camera'
#  '48\u2009MP Triple Rear & 8\u2009MP Front Camera'
#  '108\u2009MP + 20\u2009MP + 12\u2009MP Triple Rear Camera'
#  '64\u2009MP + 50\u2009MP Triple Rear & 16\u2009MP Front Camera'
#  '108\u2009MP + 8\u2009MP + 8\u2009MP Triple Rear & 16\u2009MP Front Camera'
#  '0.3\u2009MP Rear Camera'
#  '64\u2009MP + 12\u2009MP + 5\u2009MP Triple Rear & 10\u2009MP Front Camera'
#  '12\u2009MP + 5\u2009MP Dual Rear & 20\u2009MP Front Camera'
#  '50\u2009MP + 48\u2009MP + 13\u2009MP Triple Rear & 13\u2009MP Front Camera'
#  '2\u2009MP Rear Camera'
#  '13\u2009MP + 8\u2009MP + 2\u2009MP Triple Rear & 16\u2009MP Front Camera'
#  '12\u2009MP Quad Rear & 12\u2009MP Front Camera'
#  '64\u2009MP + 8\u2009MP + 2\u2009MP Triple Rear & 8\u2009MP Front Camera'
#  '16\u2009MP + 2\u2009MP + 2\u2009MP Triple Rear & 8\u2009MP Front Camera'
#  '48\u2009MP + 8\u2009MP + 5\u2009MP Triple Rear & 8\u2009MP Front Camera'
#  '20\u2009MP + 16\u2009MP Dual Rear & 16\u2009MP Front Camera'
#  '12.2\u2009MP Rear & 8\u2009MP Front Camera'
#  '8\u2009MP + 0.3\u2009MP Dual Rear & 5\u2009MP Front Camera'
#  '64\u2009MP + 5\u2009MP + 2\u2009MP Triple Rear & 8\u2009MP Front Camera'
#  '16\u2009MP + 12.2\u2009MP Dual Rear & 8\u2009MP Front Camera'
#  '108\u2009MP + 50\u2009MP + 48\u2009MP Triple Rear & 32\u2009MP Front Camera'
#  '64\u2009MP + 8\u2009MP + 2\u2009MP Triple Rear & 44\u2009MP Front Camera'
#  'No Rear Camera'
#  '50\u2009MP + Depth Sensor Dual Rear & 8\u2009MP Front Camera'
#  '64\u2009MP + 64\u2009MP + 64\u2009MP Triple Rear & 16\u2009MP Front Camera'
#  '64\u2009MP + 13\u2009MP Dual Rear & 16\u2009MP Front Camera'
#  '200\u2009MP Quad Rear & 32\u2009MP Front Camera'
#  '2.4 inches, 240\u2009x\u2009320\u2009px Display'
#  '48\u2009MP + 8\u2009MP + 2\u2009MP Triple Rear & 8\u2009MP Front Camera'
#  '48\u2009MP + 8\u2009MP + 2\u2009MP Triple Rear & 20\u2009MP Front Camera'
#  '64\u2009MP + 13\u2009MP + 5\u2009MP Triple Rear & 24\u2009MP Front Camera'
#  '50\u2009MP + 13\u2009MP + 2\u2009MP Triple Rear & 16\u2009MP Front Camera'
#  '48\u2009MP + 2\u2009MP + 2\u2009MP Triple Rear & 32\u2009MP Front Camera'
#  '64\u2009MP + 12\u2009MP + 2\u2009MP Triple Rear & 16\u2009MP Front Camera'
#  '50\u2009MP + 50\u2009MP + 16\u2009MP Triple Rear & 16\u2009MP Front Camera'
#  '48\u2009MP + 5\u2009MP + 2\u2009MP Triple Rear & 8\u2009MP Front Camera'
#  '48\u2009MP + 16\u2009MP + 2\u2009MP Triple Rear & 16\u2009MP Front Camera'
#  '13\u2009MP Rear & 7\u2009MP Front Camera' 'Android v5.0 (Lollipop)'
#  '1.8 inches, 128\u2009x\u2009160\u2009px Display'
#  '108\u2009MP + 13\u2009MP + 2\u2009MP Triple Rear & 32\u2009MP Front Camera'
#  '12\u2009MP Quad Rear & 8\u2009MP Front Camera'
#  '108\u2009MP + 16\u2009MP + 8\u2009MP Triple Rear & 25\u2009MP Front Camera'
#  '48\u2009MP Quad Rear & 8\u2009MP Front Camera'
#  '50\u2009MP + 13\u2009MP + 12\u2009MP Triple Rear & 16\u2009MP Front Camera'
#  'Memory Card Supported, upto 32\u2009GB' 'Kaios v3.0'
#  '50\u2009MP + 20\u2009MP + 12\u2009MP Triple Rear & 13\u2009MP Dual Front Camera'
#  'No FM Radio'
#  '8\u2009MP + 0.08\u2009MP Dual Rear & 5\u2009MP Front Camera'
#  '50\u2009MP Quad Rear & 13\u2009MP Dual Front Camera'
#  '64\u2009MP + 2\u2009MP Triple Rear & 16\u2009MP Front Camera'
#  '64\u2009MP + 13\u2009MP + 5\u2009MP Triple Rear & 20\u2009MP Front Camera'
#  '48\u2009MP + 8\u2009MP + 5\u2009MP Triple Rear & 16\u2009MP Front Camera'
#  '12\u2009MP + 12\u2009MP + 12\u2009MP Triple Rear & 32\u2009MP Front Camera'
#  '12\u2009MP Quad Rear & 10\u2009MP Front Camera' nan
#  '64\u2009MP + 50\u2009MP + 8\u2009MP Triple Rear & 16\u2009MP Front Camera'
#  '16\u2009MP Rear & 13\u2009MP Front Camera'
#  '13\u2009MP Quad Rear & 8\u2009MP Front Camera'
#  '48\u2009MP Quad Rear & 16\u2009MP + 2\u2009MP Dual Front Camera'
#  '48\u2009MP + 8\u2009MP + 5\u2009MP Triple Rear & 32\u2009MP Front Camera'
#  '48\u2009MP Quad Rear & 32\u2009MP Front Camera'
#  '64\u2009MP + 13\u2009MP Dual Rear & 32\u2009MP Front Camera'
#  '108\u2009MP + 8\u2009MP + 2\u2009MP Triple Rear & 20\u2009MP Front Camera'
#  '64\u2009MP + 50\u2009MP + 13\u2009MP Triple Rear & 13\u2009MP Front Camera'
#  '50\u2009MP + 13\u2009MP Dual Rear & 13\u2009MP Front Camera'
#  '16\u2009MP + 2\u2009MP Dual Rear & 8\u2009MP Front Camera'
#  '5\u2009MP + 0.3\u2009MP Dual Rear & 5\u2009MP Front Camera'
#  '5\u2009MP Rear & 5\u2009MP Front Camera'
#  '64\u2009MP Quad Rear & 16\u2009MP + 8\u2009MP Dual Front Camera'
#  '64\u2009MP + 8\u2009MP + 2\u2009MP Triple Rear & 44\u2009MP + 8\u2009MP Dual Front Camera'
#  '108\u2009MP + 13\u2009MP + 5\u2009MP Triple Rear & 20\u2009MP Front Camera'
#  '48\u2009MP Quad Rear & 32\u2009MP + 8\u2009MP Dual Front Camera'
#  'Bluetooth'
#  '16\u2009MP + 8\u2009MP + 2\u2009MP Triple Rear & 16\u2009MP Front Camera'
#  '13\u2009MP + 8\u2009MP + 2\u2009MP Triple Rear & 8\u2009MP Front Camera'
#  'Memory Card Supported, upto 16\u2009GB'
#  '20\u2009MP Rear & 13\u2009MP Front Camera'
#  '50\u2009MP + 8\u2009MP + 2\u2009MP Triple Rear & 20\u2009MP Front Camera'
#  '200\u2009MP + 50\u2009MP + 8\u2009MP Triple Rear & 50\u2009MP Front Camera'
#  '50\u2009MP + 8\u2009MP Dual Rear & 10.1\u2009MP Front Camera'
#  '50\u2009MP + 50\u2009MP + 50\u2009MP Triple Rear & 20\u2009MP Front Camera'
#  '64\u2009MP Quad Rear & 10\u2009MP Front Camera'
#  '50\u2009MP Quad Rear & 32\u2009MP Dual Front Camera'
#  '13\u2009MP + 2\u2009MP Dual Rear & 20\u2009MP Front Camera'
#  '16\u2009MP + 5\u2009MP Dual Rear & 25\u2009MP Front Camera'
#  '12\u2009MP + 12\u2009MP Dual Rear & 8\u2009MP Front Camera'
#  '47.2\u2009MP + 1.9\u2009MP Dual Rear & 12.6\u2009MP Front Camera'
#  '64\u2009MP + 2\u2009MP Dual Rear & 16\u2009MP Front Camera'
#  '48\u2009MP + 2\u2009MP Dual Rear & 16\u2009MP Front Camera'
#  '48\u2009MP + 2\u2009MP Triple Rear & 32\u2009MP Front Camera'
#  '50\u2009MP + 3\u2009MP + 2\u2009MP Triple Rear & 8\u2009MP Front Camera'
#  '50\u2009MP + 13\u2009MP + 5\u2009MP Triple Rear & 32\u2009MP Front Camera'
#  '64\u2009MP + 8\u2009MP + 5\u2009MP Triple Rear & 16\u2009MP Front Camera'
#  '108\u2009MP + 8\u2009MP + 5\u2009MP Triple Rear & 20\u2009MP Front Camera'
#  '64\u2009MP + 16\u2009MP Dual Rear & 20\u2009MP Front Camera'
#  'Memory Card Supported'
#  '12\u2009MP + 2\u2009MP + 2\u2009MP Triple Rear & 8\u2009MP Front Camera'
#  '12\u2009MP + 8\u2009MP + 8\u2009MP Triple Rear & 8\u2009MP Front Camera'
#  '12\u2009MP + 2\u2009MP Dual Rear & 8\u2009MP Front Camera'
#  '16\u2009MP + 12\u2009MP + 12\u2009MP Triple Rear & 10\u2009MP Front Camera'
#  '13\u2009MP + 2\u2009MP Dual Rear & 16\u2009MP Front Camera'
#  '108\u2009MP + 20\u2009MP + 16\u2009MP Triple Rear & 32\u2009MP Front Camera'
#  '50\u2009MP + 2\u2009MP Triple Rear & 5\u2009MP Front Camera'
#  '50\u2009MP + 13\u2009MP Dual Rear & 16\u2009MP Front Camera'
#  '50\u2009MP + 8\u2009MP + 2\u2009MP Triple Rear & 60\u2009MP Front Camera'
#  '48\u2009MP + 12\u2009MP + 5\u2009MP Triple Rear & 16\u2009MP Front Camera'
#  '50\u2009MP Quad Rear & 48\u2009MP + 8\u2009MP Dual Front Camera'
#  '48\u2009MP + 13\u2009MP + 8\u2009MP Triple Rear & 20\u2009MP Front Camera'
#  '13\u2009MP Rear & 16\u2009MP Front Camera'
#  '13\u2009MP Rear & 13\u2009MP Front Camera'
#  'Memory Card Supported, upto 128\u2009GB'
#  '13\u2009MP + 2\u2009MP Triple Rear & 8\u2009MP Front Camera'
#  '50\u2009MP + 20\u2009MP + 2\u2009MP Triple Rear & 32\u2009MP + 32\u2009MP Dual Front Camera'
#  '50\u2009MP + 12\u2009MP Dual Rear & 16\u2009MP Front Camera'
#  '50\u2009MP + 50\u2009MP Triple Rear & 16\u2009MP Front Camera'
#  '200\u2009MP Quad Rear & 16\u2009MP Front Camera'
#  '48\u2009MP + 8\u2009MP + 2\u2009MP Triple Rear & 32\u2009MP Front Camera'
#  '108\u2009MP Quad Rear & 20\u2009MP Front Camera'
#  '13\u2009MP + 2\u2009MP Dual Rear & 13\u2009MP Front Camera'
#  '64\u2009MP + 16\u2009MP + 2\u2009MP Triple Rear & 16\u2009MP Front Camera'
#  '48\u2009MP + 12.2\u2009MP + 12.2\u2009MP Triple Rear & 16\u2009MP Front Camera'
#  '40\u2009MP Quad Rear & 32\u2009MP Dual Front Camera'
#  '24\u2009MP + 10\u2009MP + 5\u2009MP Triple Rear & 24\u2009MP Front Camera'
#  '24\u2009MP + 8\u2009MP + 5\u2009MP Triple Rear & 24\u2009MP Front Camera'
#  '1.77 inches, 240\u2009x\u2009320\u2009px Display'
#  '108\u2009MP + 64\u2009MP + 16\u2009MP Triple Rear & 32\u2009MP Front Camera'
#  '16\u2009MP + 13\u2009MP + 13\u2009MP Triple Rear & 8\u2009MP Front Camera'
#  '50\u2009MP + 13\u2009MP + 2\u2009MP Triple Rear & 32\u2009MP + 16\u2009MP Dual Front Camera'
#  '64\u2009MP + 20\u2009MP + 2\u2009MP Triple Rear & 32\u2009MP + 32\u2009MP Dual Front Camera'
#  '50\u2009MP + 48\u2009MP + 32\u2009MP Triple Rear & 32\u2009MP Front Camera'
#  '50\u2009MP + 50\u2009MP + 50\u2009MP Triple Rear & 12\u2009MP Front Camera'
#  '48\u2009MP + 2\u2009MP + Depth Sensor Triple Rear & 8\u2009MP Front Camera']
# card:
#
# ['Memory Card Not Supported' 'Memory Card (Hybrid), upto 1\u2009TB'
#  'Memory Card Supported, upto 1\u2009TB' 'Android v12'
#  'Memory Card Supported' 'Android v13' 'Memory Card (Hybrid)'
#  'Memory Card Supported, upto 512\u2009GB'
#  '64\u2009MP + 10\u2009MP + 8\u2009MP Triple Rear & 32\u2009MP Front Camera'
#  '50\u2009MP Quad Rear & 16\u2009MP Front Camera'
#  'Memory Card Supported, upto 256\u2009GB' 'iOS v14'
#  'Memory Card Supported, upto 2\u2009TB'
#  'Memory Card Supported, upto 128\u2009GB' 'Android v11'
#  '5\u2009MP Rear Camera'
#  '50\u2009MP + 48\u2009MP + 32\u2009MP Triple Rear & 32\u2009MP + 32\u2009MP Dual Front Camera'
#  'Memory Card (Hybrid), upto 256\u2009GB'
#  'Memory Card (Hybrid), upto 128\u2009GB'
#  '50\u2009MP + 13\u2009MP + 8\u2009MP Triple Rear & 20\u2009MP Front Camera'
#  '2\u2009MP Rear Camera' 'Memory Card (Hybrid), upto 512\u2009GB'
#  '12\u2009MP + 12\u2009MP Dual Rear & 10\u2009MP Front Camera'
#  'Memory Card Supported, upto 32\u2009GB'
#  '50\u2009MP + 12\u2009MP + 10\u2009MP Triple Rear & 10\u2009MP + 4\u2009MP Dual Front Camera'
#  '64\u2009MP + 16\u2009MP + 8\u2009MP Triple Rear & 32\u2009MP Front Camera'
#  'Android v10'
#  '50\u2009MP + 8\u2009MP Dual Rear & 32\u2009MP Front Camera'
#  'Dual Display' 'Android v9.0 (Pie)' 'Android v12.1' 'iOS v15'
#  'Memory Card (Hybrid), upto 64\u2009GB'
#  '50\u2009MP Quad Rear & 16\u2009MP + 16\u2009MP Dual Front Camera'
#  'Memory Card Supported, upto 16\u2009GB'
#  'Memory Card Supported, upto 64\u2009GB'
#  'Memory Card Supported, upto 1000\u2009GB' '1.3\u2009MP Rear Camera'
#  '12\u2009MP + 12\u2009MP + 12\u2009MP Triple Rear & 10\u2009MP + 4\u2009MP Dual Front Camera'
#  '64\u2009MP + 13\u2009MP + 12\u2009MP Triple Rear & 32\u2009MP Front Camera'
#  nan '0.3\u2009MP Rear Camera' 'iOS v10' 'Bluetooth'
#  '64\u2009MP + 20\u2009MP + 2\u2009MP Triple Rear & Main Front Camera'
#  'iOS v14.0' 'Android v10.0' 'iOS v13'
#  '64\u2009MP + 13\u2009MP + 0.3\u2009MP Triple Rear & 10\u2009MP Front Camera'
#  'Nucleus'
#  '50\u2009MP + 16\u2009MP + 13\u2009MP Triple Rear & 32\u2009MP Front Camera'
#  '64\u2009MP + 16\u2009MP + 12\u2009MP Triple Rear & 16\u2009MP Front Camera'
#  '50\u2009MP + 13\u2009MP + 5\u2009MP Triple Rear & 12\u2009MP Front Camera'
#  '50\u2009MP + 13\u2009MP + 8\u2009MP Triple Rear & 10.7\u2009MP Front Camera'
#  'HarmonyOS v2.0' 'Browser' 'iOS v16'
#  '108\u2009MP + 13\u2009MP + 8\u2009MP Triple Rear & 20\u2009MP Front Camera'
#  '5\u2009MP Rear & 2\u2009MP Front Camera'
#  'Memory Card Supported, upto 48\u2009GB'
#  'Memory Card (Hybrid), upto 2\u2009TB' 'HarmonyOS'
#  '48\u2009MP Quad Rear Camera'
#  '50\u2009MP + 50\u2009MP + 10\u2009MP Triple Rear & 32\u2009MP Front Camera']
# os:
#
# ['Android v13' 'Android v12' 'iOS v16' 'No FM Radio' 'iOS v15' 'Bluetooth'
#  'Android v11' 'Android v10' 'iOS v13' 'HarmonyOS v2' 'iOS v15.0'
#  'Android v10.0' 'Android v8.1 (Oreo)'
#  'Memory Card Supported, upto 32\u2009GB' 'Memory Card Not Supported'
#  'iOS v13.0' 'Android v11.0' 'Android v9.0 (Pie)' 'Android v12.1'
#  'iOS v12.3' 'Memory Card Supported'
#  'Memory Card Supported, upto 256\u2009GB' '0.3\u2009MP Rear Camera'
#  'KAI OS' 'iOS v17' 'Android v4.4.2 (KitKat)' nan
#  'Android v5.1 (Lollipop)' 'Android v5.1.1 (Lollipop)' 'Hongmeng OS v3.0'
#  'Android v8.0 (Oreo)' 'Memory Card Supported, upto 64\u2009GB'
#  'Memory Card (Hybrid), upto 2\u2009TB' 'Android v6.0 (Marshmallow)'
#  'Pragati OS (Powered by Android)'
#  'Memory Card Supported, upto 16\u2009GB' 'Memory Card (Hybrid)'
#  'RTOS (Series 30+)' 'Harmony v2.0' 'Hongmeng OS v4.0'
#  'Memory Card (Hybrid), upto 256\u2009GB' 'HarmonyOS v2.0' 'Browser'
#  'Memory Card Supported, upto 128\u2009GB' 'EMUI v12'
#  'Android v7.1 (Nougat)' 'Android' 'Android v9 (Pie)'
#  '1.3\u2009MP Rear Camera']

# %%
import re
import pandas as pd

def filter_dataframe(df, column, pattern):
    mask = df[column].str.contains(pattern)
    return df.loc[mask]

# %%
# Define the expected pattern for the battery information
regex_dict = {'ram': r'\d+\u2009GB\sRAM,\s\d+\u2009GB\sinbuilt',
              'battery': r'\d+\s*mAh\s+Battery',
              'display': r'\d+\.\d+\sinches,\s\d+\u2009x\u2009\d+\u2009px',
              'camera': r'^\d+\u2009MP.*Rear\s&\s\d+\u2009MP\sFront\sCamera$'}
for column, pattern in regex_dict.items():
    df = filter_dataframe(df, column, pattern)

# %% [markdown]
# #### Testing each Regex individually

# %%
df.columns
# Out:
# Index(['model', 'price', 'rating', 'sim', 'processor', 'ram', 'battery',
#        'display', 'camera', 'card', 'os'],
#       dtype='object')

# %%
uni_list = df['card'].unique()
print(uni_list)
# Out:
# ['Memory Card Not Supported' 'Memory Card (Hybrid), upto 1\u2009TB'
#  'Memory Card Supported, upto 1\u2009TB' 'Android v12'
#  'Memory Card Supported' 'Android v13' 'Memory Card (Hybrid)'
#  'Memory Card Supported, upto 512\u2009GB'
#  'Memory Card Supported, upto 256\u2009GB'
#  'Memory Card Supported, upto 2\u2009TB' 'Android v11'
#  'Memory Card (Hybrid), upto 256\u2009GB'
#  'Memory Card (Hybrid), upto 128\u2009GB'
#  'Memory Card Supported, upto 128\u2009GB'
#  'Memory Card (Hybrid), upto 512\u2009GB'
#  'Memory Card Supported, upto 32\u2009GB' 'Android v10'
#  'Android v9.0 (Pie)' 'Android v12.1'
#  'Memory Card (Hybrid), upto 64\u2009GB'
#  'Memory Card Supported, upto 1000\u2009GB' 'iOS v10' 'Android v10.0'
#  'iOS v13' 'HarmonyOS v2.0' 'Memory Card (Hybrid), upto 2\u2009TB'
#  'HarmonyOS']

# %%
# Define the expected pattern for the battery information
pattern = r'^Memory'
pattern = r'OS|Android|UI'

column = 'card'
column = 'os'

mask = df[column].str.contains(pattern)

# Filter out the rows that don't match the pattern
# df = df.loc[mask]
df[column].unique()
# Out:
# array(['Android v13', 'Android v12', 'iOS v16', 'No FM Radio', 'iOS v15',
#        'Bluetooth', 'Android v11', 'Android v10', 'iOS v13',
#        'HarmonyOS v2', 'iOS v15.0', 'Android v10.0', 'iOS v13.0',
#        'Android v11.0', 'Android v9.0 (Pie)', 'Android v12.1',
#        'iOS v12.3', 'Android v8.1 (Oreo)', 'iOS v17',
#        'Android v5.1 (Lollipop)', 'Android v5.1.1 (Lollipop)',
#        'Android v6.0 (Marshmallow)', 'Pragati OS (Powered by Android)',
#        'Hongmeng OS v4.0', 'HarmonyOS v2.0', 'Android v8.0 (Oreo)',
#        'EMUI v12', 'Harmony v2.0', 'Android v9 (Pie)'], dtype=object)

# %%
def map_os(os):
    if pd.isna(os):
        return 'other'
    elif 'android' in os.lower():
        return 'android'
    elif 'ios' in os.lower():
        return 'ios'
    else:
        return 'other'

# Apply the function to the os column and fill remaining null values with 'other'
df['os'] = df['os'].apply(map_os).fillna('other')
df['os'].value_counts()
# Out:
# android    657
# other      200
# ios         29
# Name: os, dtype: int64

# %%
def map_memory_card_support(text):
    if pd.isna(text):
        return 'other'
    elif 'supported' in text.lower() or 'hybrid' in text.lower():
        return 'Supported'
    else:
        return 'Not Supported'
    
# Apply the function to the os column and fill remaining null values with 'other'
df['card'] = df['card'].apply(map_memory_card_support).fillna('other')
df['card'].value_counts()
# Out:
# Supported        692
# Not Supported    194
# Name: card, dtype: int64

# %%
df.count()
# Out:
# model        886
# price        886
# rating       818
# sim          886
# processor    886
# ram          886
# battery      886
# display      886
# camera       886
# card         886
# os           886
# dtype: int64

# %%
df
# Out:
#                                 model    price  rating  \
# 0                       OnePlus 11 5G  ₹54,999    89.0
# 1           OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2               Samsung Galaxy A14 5G  ₹16,499    75.0
# 3                Motorola Moto G62 5G  ₹14,999    81.0
# 4                  Realme 10 Pro Plus  ₹24,999    82.0
# ...                               ...      ...     ...
# 1015       Motorola Moto Edge S30 Pro  ₹34,990    83.0
# 1016                      Honor X8 5G  ₹14,990    75.0
# 1017  POCO X4 GT 5G (8GB RAM + 256GB)  ₹28,990    85.0
# 1018             Motorola Moto G91 5G  ₹19,990    80.0
# 1019           Samsung Galaxy M52s 5G  ₹24,990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...                                                 ...
# 1015                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1016                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1017  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1018            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1019                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                             processor  \
# 0     Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 1        Snapdragon 695, Octa Core, 2.2 GHz Processor
# 2           Exynos 1330, Octa Core, 2.4 GHz Processor
# 3       Snapdragon  695, Octa Core, 2.2 GHz Processor
# 4        Dimensity 1080, Octa Core, 2.6 GHz Processor
# ...                                               ...
# 1015    Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 1016   Snapdragon  480+, Octa Core, 2.2 GHz Processor
# 1017    Dimensity 8100, Octa Core, 2.85 GHz Processor
# 1018     Snapdragon 695, Octa Core, 2.2 GHz Processor
# 1019                              Octa Core Processor
#
#                             ram                                    battery  \
# 0     12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 100W Fast Charging
# 1      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 33W Fast Charging
# 2       4 GB RAM, 64 GB inbuilt    5000 mAh Battery with 15W Fast Charging
# 3      6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 4      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 67W Fast Charging
# ...                         ...                                        ...
# 1015   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 68.2W Fast Charging
# 1016   6 GB RAM, 128 GB inbuilt  5000 mAh Battery with 22.5W Fast Charging
# 1017   8 GB RAM, 256 GB inbuilt    5080 mAh Battery with 67W Fast Charging
# 1018   6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 1019   8 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
#
#                                                 display  \
# 0     6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1     6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2     6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3     6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4     6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# ...                                                 ...
# 1015  6.67 inches, 1080 x 2460 px, 120 Hz Display wi...
# 1016  6.5 inches, 720 x 1600 px Display with Water D...
# 1017  6.6 inches, 1080 x 2460 px, 144 Hz Display wit...
# 1018  6.8 inches, 1080 x 2400 px Display with Punch ...
# 1019  6.5 inches, 1080 x 2400 px Display with Water ...
#
#                                                  camera           card  \
# 0     50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...      Supported
# 1     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...      Supported
# 2     50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...      Supported
# 3     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...      Supported
# 4     108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...      Supported
# ...                                                 ...            ...
# 1015  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...  Not Supported
# 1016  48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP...      Supported
# 1017  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...      Supported
# 1018  108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...      Supported
# 1019  64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...      Supported
#
#            os
# 0     android
# 1     android
# 2     android
# 3     android
# 4     android
# ...       ...
# 1015    other
# 1016  android
# 1017  android
# 1018  android
# 1019  android
#
# [886 rows x 11 columns]
